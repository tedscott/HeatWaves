# %% [markdown]
# # To-DO list for Summer project
# - Summer metrics: length, start, end
#     - midlatitude averages: ocean vs land vs coasts. Should fit via OLS and also MK
#         - note start lag for ocean vs land due to higher heat capacity (also true for climatological avg start/end)
#     - spatial trends over time using MK (and also comparison with OLS slopes?)
#     - maps and graphs
#     - testing for acceleration in recent decades: poly fit of midlat avgs vs linear fit. Threshold phenomenon!
#         - Consider Foster 2025: LOESS smoothing and residual plot to show accel?
#     - Accumulated heat -> energy needed for cooling. Threshold phenomenon!
#         - show acceleration via statistical test e.g. Foster 2025 as above
#     - Gradient of summer start and end are changing - getting steeper over time for all surface types. Land has overall steepest slopes as expected.
#     - Check the gradient for each location and year at the climatological start/end to show it is getting steeper over time because a sinusoid gets steeper as the curve moves upward through the 75th percentile temp
#     - Need to confirm/compare findings with ~4-6 observational stations from GHCN-Daily. Will also make for a nice figure and show that it isn't just in ERA5.
# - Methods comparison: polynomial fit vs Fourier fit
#     - RMSE for each fit type - midlatitude averages over time, spatial maps
#     - Visuals showing applicability: key cases with poly no summer vs Fourier yes summer (both against climatology and also individual years), ocean vs land visual of timeseries
#     - Climatology 1990-2023 for each grid point in NH as objective since it best represents the "average shape of the time series for that location"
#     - Compare RMSE of Fourier vs Poly to 30-day rolling avg of climatological time series by DOY for each location
#         - I do this because the climatology represents the typical shape of the time series at that location
#         - key cases with poly no summer vs Fourier, ocean vs land
#     - Gradient of 30-day rolling avg of that climatology, compare RMSE with Poly and Fourier. Poly just can't fit the shape and sharpness of changes esp over land
#         - Latitude dependence of RMSE/goodness of fit: poly vs Fourier
#     - Caution about how poly fits lead to different summer metrics and different trends in those metrics
# - Day of Max Temp in Summer: is there an avg trend for midlatitudes (use MK or OLS)
#         - Spatial trends via MK

# %% [markdown]
# #### For the GHCND results, make a visual kinda like <br> ![image.png](attachment:aa2fa7c3-98be-4870-adb1-bd61d38825a5.png)

# %% [markdown]
# ## After upgrading to Mac OS 15.4.X my environment was broken! Created a new conda environment (was 'climate' now 'summer') with all the same packages by following the steps at: https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#building-identical-conda-environments   <br> also, I was able ot repair the old one via the steps here: https://stackoverflow.com/questions/79550279/import-numpy-failed-after-upgrading-macos-to-15-4 but decided to try the new env with updated packages since it has been so long since I updated anything

# %% [markdown]
# ## I created what should be a working environment.yml on 2025-04-30 in /Users/tedscott/Google Drive/My Drive/PhD Work/Codes/HeatWaves/HeatWaves
