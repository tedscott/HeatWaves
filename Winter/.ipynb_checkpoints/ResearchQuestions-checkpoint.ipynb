# %% [markdown]
# # Research Q's that have come up now that I'm checking the trends and data

# %% [markdown]
# ### 2026-08-26
# - Is there a correlation between Day of Tmax and AccHeat? Do earlier max T days mean more accumulated heat in summer? Connected with Pfleiderer et al 2026: https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2026EF008241 which attributes a similar effect to soil moisture depletion in Europe
# - - Checked in WinterSummerDaysTminTmax notebook and looks like a weak correlation over Europe in recent decades
# - Can we explain the persistence of spring length? It appears that both winter and autumn are the sacrifical seasons, which makes sense as they are the "colder" seasons?
# -  Is there acceleration in the timing of the first WLD, is it moving later faster, especially over ocean?
# -  Is there acceleration in the timing of the first SLD, esp over land?
# -  WinterStart and End slopes over ocean are much faster than land, also winter length
