# %% [markdown]
# ![image.png](attachment:4dc1b4d5-968c-4531-822b-427b8299b17a.png)

# %% [markdown]
# ### build that thing

# %% [markdown]
# $T(t) = T_{0} + \displaystyle\sum_{k=1}^{4}[A_{k}\cos(\omega_{k}t)+B_{k}\sin(\omega_{k}t)]$
