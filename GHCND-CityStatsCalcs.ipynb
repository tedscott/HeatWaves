# %%
import pandas as pd
import numpy as np

# %%
input_path = "../../../Data/GHCND/montreal_summer_stats.csv"
df_summ = pd.read_csv(input_path)
df_summ
# Out:
#     Unnamed: 0  Year  SummerStart  SummerEnd  StartGrad   EndGrad  \
# 0            0  1961          170        263   0.155713 -0.180622
# 1            1  1962          155        242   0.121100 -0.144712
# 2            2  1963          154        233   0.203207 -0.121691
# 3            3  1964          147        241   0.177692 -0.112052
# 4            4  1965          156        243   0.127488 -0.134544
# 5            5  1966          160        239   0.226310 -0.182865
# 6            6  1967          161        252   0.158636 -0.211193
# 7            7  1968          167        257   0.103949 -0.143386
# 8            8  1969          163        252   0.188152 -0.179670
# 9            9  1970          155        254   0.213661 -0.129582
# 10          10  1971          155        256   0.201131 -0.119768
# 11          11  1972          153        251   0.151845 -0.182726
# 12          12  1973          157        253   0.196579 -0.240207
# ...

# %%
df_summ.query("(Year <=1970)").SummerLength.mean()
# Out:
# np.float64(89.8)

# %%
df_summ.query("(Year >=2014)").SummerLength.mean()
# Out:
# np.float64(102.5)

# %%
df_summ.query("(Year > 1990) & (Year <= 2000)").SummerLength.mean()
# Out:
# np.float64(68.5)

# %%
df_summ.query("(Year >=2014)").SummerEnd.mean()
# Out:
# np.float64(261.4)

# %%
df_summ.query("(Year <=1970)").SummerEnd.mean()
# Out:
# np.float64(248.8)

# %%
# toronto
input_path = "../../../Data/GHCND/toronto_ont_summer_stats.csv"
df_summ = pd.read_csv(input_path)
df_summ
# Out:
#     Unnamed: 0  Year  SummerStart  SummerEnd  StartGrad   EndGrad  \
# 0            0  1961          167        264   0.179406 -0.178050
# 1            1  1962          148        250   0.119715 -0.154788
# 2            2  1963          160        240   0.189688 -0.135459
# 3            3  1964          160        235   0.132678 -0.120557
# 4            4  1965          177        236   0.058178 -0.088667
# ..         ...   ...          ...        ...        ...       ...
# 58          58  2019          162        258   0.174103 -0.251686
# 59          59  2020          154        252   0.280900 -0.206033
# 60          60  2021          150        266   0.143323 -0.216700
# 61          61  2022          151        258   0.183307 -0.197952
# 62          62  2023          151        263   0.147676 -0.193283
#
#     SummerLength  SummerAccHeat  SummerTmaxDay  SummerTavg
# 0             98         357.05            243  293.634184
# ...

# %%
df_summ.query("(Year >=2014)").SummerLength.mean()
# Out:
# np.float64(109.9)
