# %% [markdown]
# # Analyze trends in Winter & Summer Days, plus Tmin and Tmax

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from cartopy import crs as ccrs, feature as cfeature
import netCDF4
from netCDF4 import Dataset
from datetime import datetime as dt

import scipy.stats as stats
from sklearn import linear_model
import statsmodels.api as sm
import seaborn as sns
from statsmodels.nonparametric.smoothers_lowess import lowess as  sm_lowess
import pwlf #piecewise linear fits

# for confidence bands on lowess
import scipy.interpolate

# to get rid of runtime warnings when OLS fits hit a divide by zero - handled by setting R2 and p-vals appropriately
import warnings
warnings.filterwarnings('ignore')

# %%
# latitude & longitude ranges for NH and SH midlatitudes so they will be easy to adjust
nh_min = 23.5
nh_max = 70
sh_min = -23.5
sh_max = -70

# %% [markdown]
# ## Load LSM for filtering

# %%
file_path = '../../../../Data/ERA5-global/ERA5-2023-09-01-CoordFixed-LSM.nc'
ds_lsm = xr.open_dataset(file_path)
ds_lsm
# Out:
# <xarray.Dataset> Size: 8MB
# Dimensions:  (lat: 721, lon: 1440)
# Coordinates:
#   * lat      (lat) float32 3kB 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * lon      (lon) float32 6kB -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
# Data variables:
#     lsm      (lat, lon) float64 8MB ...

# %% [markdown]
# ### Also load threshold temps

# %%
file_path_25 = '../../../../Data/ERA5-global/Baseline/computed_1961-1990-full_25th.nc'
file_path_75 = '../../../../Data/ERA5-global/Baseline/computed_1961-1990-full_75th.nc'
c_25 = xr.open_dataarray(file_path_25)
c_75 = xr.open_dataarray(file_path_75)

# %%
c_75
# Out:
# <xarray.DataArray 't2m' (lat: 721, lon: 1440)> Size: 8MB
# [1038240 values with dtype=float64]
# Coordinates:
#   * lat       (lat) float64 6kB -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lon       (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#     quantile  float64 8B ...
# Attributes:
#     long_name:  75th percentile 2m Temperature for the data across available ...
#     units:      K

# %%
# where is c_75 near the thermal comfort level of ~ 23C?
# Global summer length for the year
fig = plt.figure(figsize=(12,6))

# assign axis and def projection to use
ax = plt.axes(projection=ccrs.Robinson(central_longitude=0))

# add coastlines and grid
ax.coastlines()
ax.gridlines()

c_75.where(((c_75.lat <= -23.5) | (c_75.lat >= 23.5)) & (c_75 >= (273 + 23))).plot(
    ax=ax,
    transform=ccrs.PlateCarree(), # assign map projection
    #vmin=50,
    #vmax=150, # define range to include an entire year
    cmap="coolwarm"#"YlOrRd"#cmap="coolwarm"
)

plt.title("Where 75th percentile is >= 23$^{\circ}$C")#+" using 1961-1990 baseline")
#plt.savefig("./Plots/"+str(input_year)+"_SummerMeanHS_global.png")
plt.show()

# %% [markdown]
# ## * Build and write out the full data set including the LSM

# %%
# %%time

# takes ~6 min to load

# start with one year and lsm and add a coordinate for the year
year = 1961
input_path = '../../../../Data/ERA5-global/Analysis/New-Fourier/Seasons/'+str(year)+'_summer_winter_days.nc'
ds_base = xr.open_dataset(input_path)
ds_base = ds_base.merge(ds_lsm) # add lsm
#ds_base = ds_base.merge(results_ds) # add coastal flag
ds_base = ds_base.expand_dims("time").assign_coords(time=("time", [dt(year,1,1)]))

# loop thru remaining years and also add time coord
input_years = np.arange(1962,2026,1)

for year in input_years:
    input_path = '../../../../Data/ERA5-global/Analysis/New-Fourier/Seasons/'+str(year)+'_summer_winter_days.nc'
    ds_i = xr.open_dataset(input_path)
    ds_i = ds_i.merge(ds_lsm)
    #ds_i = ds_i.merge(results_ds)
    ds_i = ds_i.expand_dims("time").assign_coords(time=("time", [dt(year,1,1)]))
    ds_base = ds_base.merge(ds_i)

ds_base
# Out:
# CPU times: user 1min 43s, sys: 3min 16s, total: 4min 59s
# Wall time: 5min 47s
# <xarray.Dataset> Size: 6GB
# Dimensions:         (lat: 721, lon: 1440, time: 65)
# Coordinates:
#   * lat             (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * lon             (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * time            (time) datetime64[us] 520B 1961-01-01 ... 2025-01-01
# Data variables:
#     FirstWLD        (time, lat, lon) float64 540MB 70.0 70.0 ... 180.0 180.0
#     LastWLD         (time, lat, lon) float64 540MB 273.0 273.0 ... 234.0 234.0
#     FirstSLD        (time, lat, lon) float64 540MB 116.0 116.0 ... 129.0 129.0
#     LastSLD         (time, lat, lon) float64 540MB 361.0 361.0 ... 283.0 283.0
#     DayOfTmax       (time, lat, lon) float64 540MB 179.0 179.0 ... 185.0 185.0
#     Tmax            (time, lat, lon) float64 540MB 249.2 249.2 ... 274.6 274.6
#     DayOfTmin       (time, lat, lon) float64 540MB 224.0 224.0 ... 222.0 222.0
# ...

# %%
# update attributes
ds_base.FirstWLD.attrs["long_name"] = "First day with mean T2m at or below winter threshold for the year (DOY in [1,365])"
ds_base.FirstWLD.attrs["units"] = "Day of year"

ds_base.LastWLD.attrs["long_name"] = "Last day with mean T2m at or below winter threshold for the year (DOY in [1,365])"
ds_base.LastWLD.attrs["units"] = "Day of year"

ds_base.FirstSLD.attrs["long_name"] = "First day with mean T2m at or above summer threshold for the year (DOY in [1,365])"
ds_base.FirstSLD.attrs["units"] = "Day of year"

ds_base.LastSLD.attrs["long_name"] = "Last day with mean T2m at or above summer threshold for the year (DOY in [1,365])"
ds_base.LastSLD.attrs["units"] = "Day of year"

ds_base.DayOfTmax.attrs["long_name"] = "Day of max mean T2m during the year where summer is centered"
ds_base.DayOfTmax.attrs["units"] = "Day of year"

ds_base.Tmax.attrs["long_name"] = "Max daily mean T2m during the year where summer is centered"
ds_base.Tmax.attrs["units"] = "Degrees [K]"

ds_base.DayOfTmin.attrs["long_name"] = "Day of min mean T2m during the year where winter is centered"
ds_base.DayOfTmin.attrs["units"] = "Day of year"

ds_base.Tmin.attrs["long_name"] = "Min daily mean T2m during the year where winter is centered"
ds_base.Tmin.attrs["units"] = "Degrees [K]"

ds_base.WinterlikeDays.attrs["long_name"] = "Number of days during the year where winter is centered with mean T2m at or below threshold"
ds_base.WinterlikeDays.attrs["units"] = "Days"

ds_base.SummerlikeDays.attrs["long_name"] = "Number of days during the year where summer is centered with mean T2m at or above threshold"
ds_base.SummerlikeDays.attrs["units"] = "Days"

ds_base.lsm.attrs["long_name"] = "Land-sea mask - a measure of the amount of land in the cell"
ds_base.lsm.attrs["units"] = "(0 - 1)"

ds_base
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:         (lat: 721, lon: 1440, time: 65)
# Coordinates:
#   * lat             (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * lon             (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
#   * time            (time) datetime64[us] 520B 1961-01-01 ... 2025-01-01
# Data variables:
#     FirstWLD        (time, lat, lon) float64 540MB 70.0 70.0 ... 180.0 180.0
#     LastWLD         (time, lat, lon) float64 540MB 273.0 273.0 ... 234.0 234.0
#     FirstSLD        (time, lat, lon) float64 540MB 116.0 116.0 ... 129.0 129.0
#     LastSLD         (time, lat, lon) float64 540MB 361.0 361.0 ... 283.0 283.0
#     DayOfTmax       (time, lat, lon) float64 540MB 179.0 179.0 ... 185.0 185.0
#     Tmax            (time, lat, lon) float64 540MB 249.2 249.2 ... 274.6 274.6
#     DayOfTmin       (time, lat, lon) float64 540MB 224.0 224.0 ... 222.0 222.0
#     Tmin            (time, lat, lon) float64 540MB 208.8 208.8 ... 243.8 243.8
# ...

# %%
# write out complete dataset with LSM and Coastal flags
output_path = '../../../../Data/ERA5-global/Analysis/New-Fourier/Seasons/1961-2025_ALL_summer_winter_days.nc'
ds_base.to_netcdf(output_path)

# %%
! ls -al "../../../../Data/ERA5-global/Analysis/New-Fourier/Seasons"
# Out:
# total 30600408
# drwxr-xr-x@ 70 tedscott  staff        2240 Aug 18 14:55 .
# drwx------@ 92 tedscott  staff        2944 Aug 12 13:39 ..
# -rw-r--r--@  1 tedscott  staff        6148 Aug 17 15:36 .DS_Store
# -rw-r--r--@  1 tedscott  staff    83091824 Aug 14 10:49 1961_summer_winter_days.nc
# -rw-r--r--@  1 tedscott  staff  4327418724 Aug 17 15:36 1961-2025_ALL_season_stats.nc
# -rw-r--r--   1 tedscott  staff  5938769415 Aug 18 14:55 1961-2025_ALL_summer_winter_days.nc
# -rw-r--r--@  1 tedscott  staff    83091824 Aug 14 11:25 1962_summer_winter_days.nc
# -rw-r--r--@  1 tedscott  staff    83091824 Aug 14 12:01 1963_summer_winter_days.nc
# -rw-r--r--@  1 tedscott  staff    83091824 Aug 14 12:37 1964_summer_winter_days.nc
# -rw-r--r--@  1 tedscott  staff    83091824 Aug 14 13:11 1965_summer_winter_days.nc
# -rw-r--r--@  1 tedscott  staff    83091824 Aug 14 13:46 1966_summer_winter_days.nc
# -rw-r--r--@  1 tedscott  staff    83091824 Aug 14 14:22 1967_summer_winter_days.nc
# ...

# %% [markdown]
# # **********

# %% [markdown]
# # *** JUMP here after first running

# %%
ds = xr.open_dataset('../../../../Data/ERA5-global/Analysis/New-Fourier/Seasons/1961-2025_ALL_summer_winter_days.nc')
ds
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:         (time: 65, lat: 721, lon: 1440)
# Coordinates:
#   * time            (time) datetime64[ns] 520B 1961-01-01 ... 2025-01-01
#   * lat             (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * lon             (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
# Data variables:
#     FirstWLD        (time, lat, lon) float64 540MB ...
#     LastWLD         (time, lat, lon) float64 540MB ...
#     FirstSLD        (time, lat, lon) float64 540MB ...
#     LastSLD         (time, lat, lon) float64 540MB ...
#     DayOfTmax       (time, lat, lon) float64 540MB ...
#     Tmax            (time, lat, lon) float64 540MB ...
#     DayOfTmin       (time, lat, lon) float64 540MB ...
#     Tmin            (time, lat, lon) float64 540MB ...
#     WinterlikeDays  (time, lat, lon) float64 540MB ...
#     SummerlikeDays  (time, lat, lon) float64 540MB ...
#     lsm             (time, lat, lon) float64 540MB ...

# %%
# find weights (this is a regular grid so we can use cos(latitude))
weights = np.cos(np.deg2rad(ds.lat))
weights.name = "weights"

# split on land vs ocean
ds_land = ds.where(ds.lsm > 0.5)
ds_ocean = ds.where(ds.lsm <= 0.5)

# %% [markdown]
# ### Split land vs ocean

# %%
# %%time

# takes 20 sec

# latitude & longitude ranges for NH and SH midlatitudes so they will be easy to adjust
nh_min = 23.5
nh_max = 70
sh_min = -23.5
sh_max = -70

# datasets of weighted averages for the midlatitudes
nh_land_full = ds_land.where(((ds_land.lat >= nh_min) & (ds_land.lat <= nh_max))).weighted(weights).mean(dim=['lat','lon'])

sh_land_full = ds_land.where(((ds_land.lat >= sh_max) & (ds_land.lat <= sh_min))).weighted(weights).mean(dim=['lat','lon'])

nh_ocean_full = ds_ocean.where(((ds_ocean.lat >= nh_min) & (ds_ocean.lat <= nh_max))).weighted(weights).mean(dim=['lat','lon'])

sh_ocean_full = ds_ocean.where(((ds_ocean.lat >= sh_max) & (ds_ocean.lat <= sh_min))).weighted(weights).mean(dim=['lat','lon'])
# Out:
# CPU times: user 9.22 s, sys: 7.3 s, total: 16.5 s
# Wall time: 17.7 s

# %% [markdown]
# ### WLD and SLD

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.WinterlikeDays, color="blue", label="Ocean WLD")
plt.plot(nh_land_full.time.dt.year, nh_land_full.WinterlikeDays, color="orange", label="Land WLD")
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("Days")
plt.title("NH Midlatitude Summer and Winter Like Days, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
plt.legend()

plt.subplot(1,2,2)
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.WinterlikeDays, color="blue", label="Ocean WLD")
plt.plot(sh_land_full.time.dt.year, sh_land_full.WinterlikeDays, color="orange", label="Land WLD")
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("Days")
plt.title("SH Midlatitude Summer and Winter Like Days, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
plt.legend()

plt.show()

# %% [markdown]
# #### **** should compare to summer and winter lengths

# %%
# load in the stats for summer and winter length

# %%
# plt.figure(figsize=(15,5))
# plt.subplot(1,2,1)
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.WinterLength, color="blue", label="Ocean WLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.WinterlikeDays, color="orange", label="Land WLD")
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land SLD")
# plt.xlabel("Year")
# plt.ylabel("Winter Like Days")
# plt.title("NH Midlatitude Summer and Winter Like Days, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
# plt.legend()

# plt.subplot(1,2,2)
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.WinterlikeDays, color="blue", label="Ocean WLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.WinterlikeDays, color="orange", label="Land WLD")
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land SLD")
# plt.xlabel("Year")
# plt.ylabel("Winter Like Days")
# plt.title("SH Midlatitude Summer and Winter Like Days, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
# plt.legend()

# plt.show()

# %% [markdown]
# ## Day of Tmax vs first SLD, Day of Tmin vs first WLD (or subtract and see if the day is shifting relative to the first day

# %%
# first just the mean for the hemispheres First SLD
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.FirstSLD, color="blue", label="Ocean")
plt.plot(nh_land_full.time.dt.year, nh_land_full.FirstSLD, color="red", label="Land")
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("NH Midlatitude: FirstSLD, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
plt.legend()

plt.subplot(1,2,2)
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.FirstSLD, color="blue", label="Ocean")
plt.plot(sh_land_full.time.dt.year, sh_land_full.FirstSLD, color="red", label="Land")
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("SH Midlatitude: FirstSLD, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
plt.legend()

plt.show()

# %% [markdown]
# #### Mean day of Tmax looks fairly stable

# %%
# first just the mean for the hemispheres DayOfTmax
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.DayOfTmax, color="blue", label="Ocean")
plt.plot(nh_land_full.time.dt.year, nh_land_full.DayOfTmax, color="red", label="Land")
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("NH Midlatitude: DayOfTmax, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
plt.legend()

plt.subplot(1,2,2)
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.DayOfTmax, color="blue", label="Ocean")
plt.plot(sh_land_full.time.dt.year, sh_land_full.DayOfTmax, color="red", label="Land")
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("SH Midlatitude: DayOfTmax, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
plt.legend()

plt.show()

# %% [markdown]
# ### so the FirstSLD is what is moving

# %%
# first just the mean for the hemispheres
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.FirstSLD - nh_ocean_full.DayOfTmax, color="blue", label="Ocean")
plt.plot(nh_land_full.time.dt.year, nh_land_full.FirstSLD - nh_land_full.DayOfTmax, color="red", label="Land")
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("Difference in Days")
plt.title("NH Midlatitude: FirstSLD - DayOfTmax, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
plt.legend()

plt.subplot(1,2,2)
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.FirstSLD - sh_ocean_full.DayOfTmax, color="blue", label="Ocean")
plt.plot(sh_land_full.time.dt.year, sh_land_full.FirstSLD - sh_land_full.DayOfTmax, color="red", label="Land")
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("Difference in Days")
plt.title("SH Midlatitude: FirstSLD - DayOfTmax, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
plt.legend()

plt.show()

# %% [markdown]
# ### now WLD

# %%
# first just the mean for the hemispheres First WLD
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.FirstWLD, color="blue", label="Ocean")
plt.plot(nh_land_full.time.dt.year, nh_land_full.FirstWLD, color="red", label="Land")
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean WLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land WLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("NH Midlatitude: FirstWLD, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
plt.legend()

plt.subplot(1,2,2)
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.FirstWLD, color="blue", label="Ocean")
plt.plot(sh_land_full.time.dt.year, sh_land_full.FirstWLD, color="red", label="Land")
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean WLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land WLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("SH Midlatitude: FirstWLD, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
plt.legend()

plt.show()

# %% [markdown]
# #### Mean day of Tmin LAND: stable for SH but moving later for NH

# %%
# first just the mean for the hemispheres DayOfTmax
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.DayOfTmin, color="blue", label="Ocean")
plt.plot(nh_land_full.time.dt.year, nh_land_full.DayOfTmin, color="red", label="Land")
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("NH Midlatitude: DayOfTmin, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
plt.legend()

plt.subplot(1,2,2)
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.DayOfTmin, color="blue", label="Ocean")
plt.plot(sh_land_full.time.dt.year, sh_land_full.DayOfTmin, color="red", label="Land")
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean SLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land SLD")
plt.xlabel("Year")
plt.ylabel("DOY")
plt.title("SH Midlatitude: DayOfTmin, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
plt.legend()

plt.show()

# %% [markdown]
# ### so the FirstWLD is what is moving faster? Esp for ocean?

# %%
# first just the mean for the hemispheres
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.FirstWLD - nh_ocean_full.DayOfTmin, color="blue", label="Ocean")
plt.plot(nh_land_full.time.dt.year, nh_land_full.FirstWLD - nh_land_full.DayOfTmin, color="red", label="Land")
# plt.plot(nh_ocean_full.time.dt.year, nh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean WLD")
# plt.plot(nh_land_full.time.dt.year, nh_land_full.SummerlikeDays, color="red", label="Land WLD")
plt.xlabel("Year")
plt.ylabel("Difference in Days")
plt.title("NH Midlatitude: FirstWLD - DayOfTmin, \nOcean vs Land, 1961-2025 \n[23.5, 70]$^\circ$N")
plt.legend()

plt.subplot(1,2,2)
plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.FirstWLD - sh_ocean_full.DayOfTmin, color="blue", label="Ocean")
plt.plot(sh_land_full.time.dt.year, sh_land_full.FirstWLD - sh_land_full.DayOfTmin, color="red", label="Land")
# plt.plot(sh_ocean_full.time.dt.year, sh_ocean_full.SummerlikeDays, color="lightblue", label="Ocean WLD")
# plt.plot(sh_land_full.time.dt.year, sh_land_full.SummerlikeDays, color="red", label="Land WLD")
plt.xlabel("Year")
plt.ylabel("Difference in Days")
plt.title("SH Midlatitude: FirstWLD - DayOfTmin, \nOcean vs Land, 1961-2025 \n[-23.5, -70]$^\circ$S")
plt.legend()

plt.show()

# %% [markdown]
# ## Time to do trends for all vars - land vs ocean

# %%
# %%time

# 35 sec
nh_land_an = ds_land.sel(time=slice('1990','2025')).where(((ds_land.lat >= nh_min) & (ds_land.lat <= nh_max))).weighted(weights).mean(dim=['lat','lon'])

sh_land_an = ds_land.sel(time=slice('1990','2025')).where(((ds_land.lat >= sh_max) & (ds_land.lat <= sh_min))).weighted(weights).mean(dim=['lat','lon'])

nh_ocean_an = ds_ocean.sel(time=slice('1990','2025')).where(((ds_ocean.lat >= nh_min) & (ds_ocean.lat <= nh_max))).weighted(weights).mean(dim=['lat','lon'])

sh_ocean_an = ds_ocean.sel(time=slice('1990','2025')).where(((ds_ocean.lat >= sh_max) & (ds_ocean.lat <= sh_min))).weighted(weights).mean(dim=['lat','lon'])


# adding in baseline period to use for trends in the paper
# nh_land_base = ds.sel(time=slice('1961','1990')).where((ds.lsm > 0.5)  & (ds.Coastal == False) & #& (ds.SummerMeanT > 0)
#                                                           ((ds.lat >= nh_min) & (ds.lat <= nh_max))).weighted(weights).mean(dim=['lat','lon'])

# nh_coast_base = ds.sel(time=slice('1961','1990')).where((ds.Coastal)  & #& (ds.SummerMeanT > 0)
#                                                            ((ds.lat >= nh_min) & (ds.lat <= nh_max))).weighted(weights).mean(dim=['lat','lon'])

# sh_land_base = ds.sel(time=slice('1961','1990')).where((ds.lsm > 0.5)  & (ds.Coastal == False) & #& (ds.SummerMeanT > 0)
#                                                           ((ds.lat >= sh_max) & (ds.lat <= sh_min))).weighted(weights).mean(dim=['lat','lon'])

# sh_coast_base = ds.sel(time=slice('1961','1990')).where((ds.Coastal)  & #& (ds.SummerMeanT > 0)
#                                                            ((ds.lat >= sh_max) & (ds.lat <= sh_min))).weighted(weights).mean(dim=['lat','lon'])
# Out:
# CPU times: user 4.94 s, sys: 3.69 s, total: 8.63 s
# Wall time: 9.81 s

# %%
plot_vars = list(ds_land.data_vars)
remove_me = {'lsm'}
plot_vars = [item for item in plot_vars if item not in remove_me]
plot_vars
# Out:
# ['FirstWLD',
#  'LastWLD',
#  'FirstSLD',
#  'LastSLD',
#  'DayOfTmax',
#  'Tmax',
#  'DayOfTmin',
#  'Tmin',
#  'WinterlikeDays',
#  'SummerlikeDays']

# %%
# plot properties so I can more easily tweak them
s = 18
lw = 4
alpha = 0.6
fs = 20

sns.set_theme(style="darkgrid")

# %%
# %%time

# takes 30 sec

# loop through all plot variables
for i,v in enumerate(plot_vars):

    # create blank fig
    fig = plt.figure(figsize = (20,5), layout='constrained')
    
    # Full Time Period NH
    ax1 = fig.add_subplot(1,4,1)

    # linear fits for slope
    x_land = nh_land_full.time.dt.year.values
    y_land = nh_land_full[v].values
    coefs_land, V = np.polyfit(x_land, y_land, 1, cov=True)
    poly_land = np.poly1d(coefs_land)
    slope_land = np.round(coefs_land[0],2)
    slope_land_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_land)
    ss_total = np.sum((y_land - ymean)**2)
    ss_res = np.sum((y_land - poly_land(x_land))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_land = np.round(1 - (ss_res / ss_total),2)

    # linear fits for slope
    x_ocean = nh_ocean_full.time.dt.year.values
    y_ocean = nh_ocean_full[v].values
    coefs_ocean, V = np.polyfit(x_ocean, y_ocean, 1, cov=True)
    poly_ocean = np.poly1d(coefs_ocean)
    slope_ocean = np.round(coefs_ocean[0],2)
    slope_ocean_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_ocean)
    ss_total = np.sum((y_ocean - ymean)**2)
    ss_res = np.sum((y_ocean - poly_ocean(x_ocean))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_ocean = np.round(1 - (ss_res / ss_total),2)
    
    # plot data
    ax1.scatter(x_ocean, y_ocean, label="NH Ocean", c="blue", s=s, alpha=alpha)
    ax1.plot(x_ocean, poly_ocean(x_ocean), linestyle="dashed", linewidth=lw, color='blue', 
         label="Slope = "+str(slope_ocean)+" $\pm$ "+str(slope_ocean_sd)+" $R^2$ = "+str(r_squared_ocean))
    ax1.scatter(x_land, y_land, label="NH Land", marker='*', facecolors='brown', edgecolors='brown', s=s, alpha=alpha)
    ax1.plot(x_land, poly_land(x_land), linestyle="dotted", linewidth=lw, color='brown',
         label="Slope = "+str(slope_land)+" $\pm$ "+str(slope_land_sd)+" $R^2$ = "+str(r_squared_land))
    ax1.set_title("Northern Hemisphere \n" + v + " (1961-2025)", fontsize = fs)
    # Annotation
    ann_y = (ax1.get_yticks())[-3]+0
    ann_x = np.mean(ax1.get_xticks())-5
    # plot shows mean slope across all surface types for clarity
    mean_slope = np.sqrt(slope_ocean**2 + slope_land**2)/np.sqrt(2) * 10 # to get days per decade
    if (slope_ocean < 0):
        mean_slope = mean_slope * -1
    ax1.text(ann_x, ann_y, 
             ''+str(np.round(mean_slope,1))+r' $\frac{Y}{10 yrs}$', fontsize=28, color='purple', fontweight='bold')
             #''+str(np.round((slope_ocean+slope_land)*5,1))+r' $\frac{days}{decade}$', fontsize=28, color='purple', fontweight='bold')
    plt.tick_params('x', labelsize=16)
    plt.tick_params('y', labelsize=16)
    if ((i == 5) | (i == 7)):
        ylabel = '[K]'
    elif i >= 8:
        ylabel = 'Days'
    else:
        ylabel = 'DOY'
    ax1.set_ylabel(ylabel, fontsize=fs)
    #ax1.legend(loc='best')

    # Full time period SH
    ax2 = fig.add_subplot(1,4,2, sharey=ax1)

    # linear fits for slope
    x_land = sh_land_full.time.dt.year.values
    y_land = sh_land_full[v].values
    coefs_land, V = np.polyfit(x_land, y_land, 1, cov=True)
    poly_land = np.poly1d(coefs_land)
    slope_land = np.round(coefs_land[0],2)
    slope_land_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_land)
    ss_total = np.sum((y_land - ymean)**2)
    ss_res = np.sum((y_land - poly_land(x_land))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_land = np.round(1 - (ss_res / ss_total),2)

    # linear fits for slope
    x_ocean = sh_ocean_full.time.dt.year.values
    y_ocean = sh_ocean_full[v].values
    coefs_ocean, V = np.polyfit(x_ocean, y_ocean, 1, cov=True)
    poly_ocean = np.poly1d(coefs_ocean)
    slope_ocean = np.round(coefs_ocean[0],2)
    slope_ocean_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_ocean)
    ss_total = np.sum((y_ocean - ymean)**2)
    ss_res = np.sum((y_ocean - poly_ocean(x_ocean))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_ocean = np.round(1 - (ss_res / ss_total),2)
    
    # plot data
    ax2.scatter(x_ocean, y_ocean, label="SH Ocean", c="blue", s=s, alpha=alpha)
    ax2.plot(x_ocean, poly_ocean(x_ocean), linestyle="dashed", linewidth=lw, color='blue', 
         label="Slope = "+str(slope_ocean)+" $\pm$ "+str(slope_ocean_sd)+" $R^2$ = "+str(r_squared_ocean))
    ax2.scatter(x_land, y_land, label="SH Land", marker='*', facecolors='brown', edgecolors='brown', s=s, alpha=alpha)
    ax2.plot(x_land, poly_land(x_land), linestyle="dotted", linewidth=lw, color='brown',
         label="Slope = "+str(slope_land)+" $\pm$ "+str(slope_land_sd)+" $R^2$ = "+str(r_squared_land))
    ax2.set_title("Southern Hemisphere \n" + v + " (1961-2025)", fontsize = fs)
    # Annotation
    ann_y = (ax2.get_yticks())[-3]+0
    ann_x = np.mean(ax2.get_xticks())-5
    # plot shows mean slope across all surface types for clarity
    mean_slope = np.sqrt(slope_ocean**2 + slope_land**2)/np.sqrt(2) * 10 # to get days per decade
    if (slope_ocean < 0):
        mean_slope = mean_slope * -1
    ax2.text(ann_x, ann_y, 
             ''+str(np.round(mean_slope,1))+r' $\frac{Y}{10 yrs}$', fontsize=28, color='purple', fontweight='bold')
    # ax2.text(np.min(x_land)+10, np.max(y_ocean)-2, 
    #          r'$\frac{\Delta}{\Delta t} \approx $'+str(np.round((slope_ocean+slope_land)*5,1)), fontsize=28, color='purple', fontweight='bold')
    plt.tick_params('x', labelsize=16)
    plt.tick_params('y', labelsize=6, labelleft=False)
    #ax2.legend(loc='best')
    

    # Analysis time period NH
    ax3 = fig.add_subplot(1,4,3, sharey=ax1)

    # linear fits for slope
    x_land = nh_land_an.time.dt.year.values
    y_land = nh_land_an[v].values
    coefs_land, V = np.polyfit(x_land, y_land, 1, cov=True)
    poly_land = np.poly1d(coefs_land)
    slope_land = np.round(coefs_land[0],2)
    slope_land_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_land)
    ss_total = np.sum((y_land - ymean)**2)
    ss_res = np.sum((y_land - poly_land(x_land))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_land = np.round(1 - (ss_res / ss_total),2)

    # linear fits for slope
    x_ocean = nh_ocean_an.time.dt.year.values
    y_ocean = nh_ocean_an[v].values
    coefs_ocean, V = np.polyfit(x_ocean, y_ocean, 1, cov=True)
    poly_ocean = np.poly1d(coefs_ocean)
    slope_ocean = np.round(coefs_ocean[0],2)
    slope_ocean_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_ocean)
    ss_total = np.sum((y_ocean - ymean)**2)
    ss_res = np.sum((y_ocean - poly_ocean(x_ocean))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_ocean = np.round(1 - (ss_res / ss_total),2)
    
    # plot data
    ax3.scatter(x_ocean, y_ocean, label="NH Ocean", c="blue", s=s, alpha=alpha)
    ax3.plot(x_ocean, poly_ocean(x_ocean), linestyle="dashed", linewidth=lw, color='blue', 
         label="Slope = "+str(slope_ocean)+" $\pm$ "+str(slope_ocean_sd)+" $R^2$ = "+str(r_squared_ocean))
    ax3.scatter(x_land, y_land, label="NH Land", marker='*', facecolors='brown', edgecolors='brown', s=s, alpha=alpha)
    ax3.plot(x_land, poly_land(x_land), linestyle="dotted", linewidth=lw, color='brown',
         label="Slope = "+str(slope_land)+" $\pm$ "+str(slope_land_sd)+" $R^2$ = "+str(r_squared_land))
    ax3.set_title("Northern Hemisphere \n" + v + " (1990-2025)", fontsize = fs)
    # Annotation - units in per decade
    ann_y = (ax3.get_yticks())[-3]+0
    ann_x = np.mean(ax3.get_xticks())-5
    # plot shows mean slope across all surface types for clarity
    mean_slope = np.sqrt(slope_ocean**2 + slope_land**2)/np.sqrt(2) * 10 # to get days per decade
    if (slope_ocean < 0):
        mean_slope = mean_slope * -1
    ax3.text(ann_x, ann_y, 
             ''+str(np.round(mean_slope,1))+r' $\frac{Y}{10 yrs}$', fontsize=28, color='purple', fontweight='bold')
    plt.tick_params('x', labelsize=16)
    plt.tick_params('y', labelsize=6, labelleft=False)
    #ax3.legend(loc='best')

    
    # Analysis time period SH
    ax4 = fig.add_subplot(1,4,4, sharey=ax1)

    # linear fits for slope
    x_land = sh_land_an.time.dt.year.values
    y_land = sh_land_an[v].values
    coefs_land, V = np.polyfit(x_land, y_land, 1, cov=True)
    poly_land = np.poly1d(coefs_land)
    slope_land = np.round(coefs_land[0],2)
    slope_land_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_land)
    ss_total = np.sum((y_land - ymean)**2)
    ss_res = np.sum((y_land - poly_land(x_land))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_land = np.round(1 - (ss_res / ss_total),2)

    # linear fits for slope
    x_ocean = sh_ocean_an.time.dt.year.values
    y_ocean = sh_ocean_an[v].values
    coefs_ocean, V = np.polyfit(x_ocean, y_ocean, 1, cov=True)
    poly_ocean = np.poly1d(coefs_ocean)
    slope_ocean = np.round(coefs_ocean[0],2)
    slope_ocean_sd = np.round(np.sqrt(V[0][0]),2)  
    # add in R^2 and RMSE
    ymean = np.mean(y_ocean)
    ss_total = np.sum((y_ocean - ymean)**2)
    ss_res = np.sum((y_ocean - poly_ocean(x_ocean))**2)
    #rmse = np.sqrt(ss_res/365.0)
    r_squared_ocean = np.round(1 - (ss_res / ss_total),2)
    
    # plot data
    ax4.scatter(x_ocean, y_ocean, label="SH Ocean", c="blue", s=s, alpha=alpha)
    ax4.plot(x_ocean, poly_ocean(x_ocean), linestyle="dashed", linewidth=lw, color='blue', 
         label="Slope = "+str(slope_ocean)+" $\pm$ "+str(slope_ocean_sd)+" $R^2$ = "+str(r_squared_ocean))
    ax4.scatter(x_land, y_land, label="SH Land", marker='*', facecolors='brown', edgecolors='brown', s=s, alpha=alpha)
    ax4.plot(x_land, poly_land(x_land), linestyle="dotted", linewidth=lw, color='brown',
         label="Slope = "+str(slope_land)+" $\pm$ "+str(slope_land_sd)+" $R^2$ = "+str(r_squared_land))
    ax4.set_title("Southern Hemisphere \n" + v + " (1990-2025)", fontsize = fs)
    # Annotation - units in per decade
    ann_y = (ax4.get_yticks())[-3]+0
    ann_x = np.mean(ax4.get_xticks())-5
        # plot shows mean slope across all surface types for clarity
    mean_slope = np.sqrt(slope_ocean**2 + slope_land**2)/np.sqrt(2) * 10 # to get days per decade
    if (slope_ocean < 0):
        mean_slope = mean_slope * -1
    ax4.text(ann_x, ann_y, 
             ''+str(np.round(mean_slope,1))+r' $\frac{Y}{10 yrs}$', fontsize=28, color='purple', fontweight='bold')
    
    plt.tick_params('x', labelsize=16)
    plt.tick_params('y', labelsize=6, labelleft=False)
    #ax3.legend(loc='best')


#plt.tight_layout()
plt.show()
# Out:
# CPU times: user 1.77 s, sys: 180 ms, total: 1.95 s
# Wall time: 2.07 s

# %% [markdown]
# # **** BELOW NEEDS UPDATING

# %% [markdown]
# ## Getting sidetracked briefly - correlation between AccHeat and DayOfTmax?

# %%
summer_path = "../../../../Data/ERA5-global/Analysis/New-Fourier/1961-2025_ALL_summer_stats.nc"
ds_summers = xr.open_mfdataset(summer_path)
ds_summers
# Out:
# <xarray.Dataset> Size: 5GB
# Dimensions:         (time: 65, lat: 721, lon: 1440)
# Coordinates:
#   * time            (time) datetime64[ns] 520B 1961-01-01 ... 2025-01-01
#   * lat             (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * lon             (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
# Data variables:
#     SummerStart     (time, lat, lon) float64 540MB dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
#     SummerEnd       (time, lat, lon) float64 540MB dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
#     SummerTmax      (time, lat, lon) float64 540MB dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
#     SummerHeat      (time, lat, lon) float64 540MB dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
#     SummerLength    (time, lat, lon) float64 540MB dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
#     SummerlikeDays  (time, lat, lon) float64 540MB dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
# ...

# %%
ds_heat_tmax = xr.merge([ds.DayOfTmax,ds_summers.SummerHeat])
ds_heat_tmax
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:     (lat: 721, lon: 1440, time: 65)
# Coordinates:
#   * lat         (lat) float64 6kB -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lon         (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * time        (time) datetime64[ns] 520B 1961-01-01 1962-01-01 ... 2025-01-01
# Data variables:
#     DayOfTmax   (time, lat, lon) float64 540MB ...
#     SummerHeat  (time, lat, lon) float64 540MB dask.array<chunksize=(65, 721, 1440), meta=np.ndarray>
# Attributes:
#     long_name:  Day of max mean T2m during the year where summer is centered
#     units:      Day of year

# %%
xr.corr(ds_heat_tmax.sel(time=slice('1990','2025')).DayOfTmax, ds_heat_tmax.sel(time=slice('1990','2025')).SummerHeat, dim='time').plot()

# %%
tmax_heat_corr = xr.corr(ds_heat_tmax.sel(time=slice('2010','2025')).DayOfTmax, ds_heat_tmax.sel(time=slice('2010','2025')).SummerHeat, dim='time')

# %%
# %%time

fig = plt.figure(figsize=(16,8))

ax1 = fig.add_subplot(1,1,1, projection=ccrs.Robinson(central_longitude=0))

# add coastlines and grid
ax1.coastlines()
ax1.gridlines()

tmax_heat_corr.sel(lat=slice(nh_min, nh_max)).where(tmax_heat_corr >= 0.3).plot(
    ax=ax1,
    transform=ccrs.PlateCarree(), # assign map projection
    #vmin=-0.3,
    #vmax=0.3, # define range to include an entire year
    cmap="coolwarm",#"YlOrRd"#cmap="coolwarm"
    cbar_kwargs={'shrink': 0.5}
)
ax1.set_title("Correlation between DayOfTmax and AccHeat (2010-2025)")
# Out:
# CPU times: user 510 ms, sys: 304 ms, total: 814 ms
# Wall time: 484 ms
# Text(0.5, 1.0, 'Correlation between DayOfTmax and AccHeat (2010-2025)')

# %% [markdown]
# ### Not super promising, surprisingly

# %% [markdown]
# ### what about DayOfTmax and SummerlikeDays?

# %%
ds
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:         (time: 65, lat: 721, lon: 1440)
# Coordinates:
#   * time            (time) datetime64[ns] 520B 1961-01-01 ... 2025-01-01
#   * lat             (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * lon             (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.5 179.8
# Data variables:
#     FirstWLD        (time, lat, lon) float64 540MB ...
#     LastWLD         (time, lat, lon) float64 540MB ...
#     FirstSLD        (time, lat, lon) float64 540MB ...
#     LastSLD         (time, lat, lon) float64 540MB ...
#     DayOfTmax       (time, lat, lon) float64 540MB ...
#     Tmax            (time, lat, lon) float64 540MB ...
#     DayOfTmin       (time, lat, lon) float64 540MB ...
#     Tmin            (time, lat, lon) float64 540MB ...
#     WinterlikeDays  (time, lat, lon) float64 540MB ...
#     SummerlikeDays  (time, lat, lon) float64 540MB ...
#     lsm             (time, lat, lon) float64 540MB 1.0 1.0 1.0 ... 0.0 0.0 0.0

# %%
tmax_sld_corr = xr.corr(ds.DayOfTmax.sel(time=slice('2010','2025')), ds.SummerlikeDays.sel(time=slice('2010','2025')), dim='time')

# %%
# %%time

fig = plt.figure(figsize=(16,8))

ax1 = fig.add_subplot(1,1,1, projection=ccrs.Robinson(central_longitude=0))

# add coastlines and grid
ax1.coastlines()
ax1.gridlines(draw_labels=True, linewidth=1, color='black', alpha=0.5, linestyle='--')

tmax_sld_corr.sel(lat=slice(nh_min, nh_max)).plot(#where(tmax_heat_corr >= 0.3).plot(
    ax=ax1,
    transform=ccrs.PlateCarree(), # assign map projection
    #vmin=-0.3,
    #vmax=0.3, # define range to include an entire year
    cmap="coolwarm",#"YlOrRd"#cmap="coolwarm"
    cbar_kwargs={'shrink': 0.5}
)

#ax1.set_extent((-30, 60, 23.5, 60))

provinces_50m = cfeature.NaturalEarthFeature('cultural',
                                             'admin_1_states_provinces_lines',
                                             '50m',
                                             facecolor='none')
ax1.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='black')
#ax1.add_feature(cfeature.STATES, linewidth=0.3, edgecolor='brown')
#ax1.add_feature(provinces_50m, edgecolor='black')

ax1.set_title("Correlation between DayOfTmax and SLD (2010-2025)")
# Out:
# CPU times: user 461 ms, sys: 11.1 ms, total: 472 ms
# Wall time: 471 ms
# Text(0.5, 1.0, 'Correlation between DayOfTmax and SLD (2010-2025)')

# %%
# %%time

fig = plt.figure(figsize=(16,8))

ax1 = fig.add_subplot(1,1,1, projection=ccrs.Robinson(central_longitude=0))

# add coastlines and grid
ax1.coastlines()
ax1.gridlines(draw_labels=True, linewidth=1, color='black', alpha=0.5, linestyle='--')

tmax_sld_corr.sel(lat=slice(nh_min, nh_max)).plot(#where(tmax_heat_corr >= 0.3).plot(
    ax=ax1,
    transform=ccrs.PlateCarree(), # assign map projection
    #vmin=-0.3,
    #vmax=0.3, # define range to include an entire year
    cmap="coolwarm",#"YlOrRd"#cmap="coolwarm"
    cbar_kwargs={'shrink': 0.5}
)

ax1.set_extent((-30, 60, 23.5, 60))

provinces_50m = cfeature.NaturalEarthFeature('cultural',
                                             'admin_1_states_provinces_lines',
                                             '50m',
                                             facecolor='none')
ax1.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='black')
ax1.add_feature(cfeature.STATES, linewidth=0.3, edgecolor='brown')
ax1.add_feature(provinces_50m, edgecolor='black')

ax1.set_title("Correlation between DayOfTmax and SLD (2010-2025)")
# Out:
# CPU times: user 463 ms, sys: 14.5 ms, total: 477 ms
# Wall time: 476 ms
# Text(0.5, 1.0, 'Correlation between DayOfTmax and SLD (2010-2025)')

# %%
# %%time

fig = plt.figure(figsize=(16,8))

ax1 = fig.add_subplot(1,1,1, projection=ccrs.Robinson(central_longitude=0))

# add coastlines and grid
ax1.coastlines()
ax1.gridlines(draw_labels=True, linewidth=1, color='black', alpha=0.5, linestyle='--')

tmax_sld_corr.sel(lat=slice(nh_min, nh_max)).where(tmax_sld_corr >= 0.3).plot(
    ax=ax1,
    transform=ccrs.PlateCarree(), # assign map projection
    #vmin=-0.3,
    #vmax=0.3, # define range to include an entire year
    cmap="coolwarm",#"YlOrRd"#cmap="coolwarm"
    cbar_kwargs={'shrink': 0.5}
)

ax1.set_extent((-30, 60, 23.5, 60))

provinces_50m = cfeature.NaturalEarthFeature('cultural',
                                             'admin_1_states_provinces_lines',
                                             '50m',
                                             facecolor='none')
ax1.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='black')
ax1.add_feature(cfeature.STATES, linewidth=0.3, edgecolor='brown')
ax1.add_feature(provinces_50m, edgecolor='black')

ax1.set_title("Correlation between DayOfTmax and SLD (2010-2025)")
# Out:
# CPU times: user 148 ms, sys: 9.93 ms, total: 158 ms
# Wall time: 157 ms
# Text(0.5, 1.0, 'Correlation between DayOfTmax and SLD (2010-2025)')

# %% [markdown]
# ### Weak correlation over W Europe but overall pretty noisy
