# %% [markdown]
# # look at a rolling T2m year and see what it looks like to maybe provide an argument why smoothing with Fourier is still better

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft
import seaborn as sns

from cartopy import crs as ccrs, feature as cfeature
import netCDF4
from netCDF4 import Dataset
from datetime import datetime as dt

# %%
input_year = 2023

# get this year and next year's daily mean t2m data
if input_year <= 1990:
    file_path = '../../../Data/ERA5-global/Baseline/' + str(input_year) + '/*.nc'
else:
    file_path = '../../../Data/ERA5-global/Analysis/' + str(input_year) + '/*.nc'
ds = xr.open_mfdataset(file_path)

# load into memory to speed up the summer stats processing
ds.load()

# get summer stats for the year based on Fourier fits
file_path = '../../../Data/ERA5-global/Analysis/New-Fourier/' + str(input_year) + '_summer_stats.nc'
ds_summ = xr.open_dataset(file_path)
ds_summ.load()


#test for Vancouver
input_lat = 49.246
input_lon = -123.116
curr = ds.sel(lat=input_lat, lon=input_lon, method="nearest")
curr_summ = ds_summ.sel(lat=input_lat, lon=input_lon, method="nearest")

# %%
curr, curr_summ
# Out:
# (<xarray.Dataset> Size: 6kB
#  Dimensions:      (time: 365)
#  Coordinates:
#    * time         (time) datetime64[ns] 3kB 2023-01-01 2023-01-02 ... 2023-12-31
#      realization  int64 8B 0
#      lat          float64 8B 49.25
#      lon          float64 8B -123.0
#  Data variables:
#      t2m          (time) float32 1kB 277.9 276.3 276.0 ... 283.0 283.1 279.9
#      sst          (time) float32 1kB nan nan nan nan nan ... nan nan nan nan nan
#  Attributes:
#      Conventions:  CF-1.7
#      institution:  European Centre for Medium-Range Weather Forecasts
#      history:      2024-06-12T22:52 GRIB to CDM+CF via cfgrib-0.9.9.1/ecCodes-...
#      source:       ECMWF,
#  <xarray.Dataset> Size: 88B
#  Dimensions:       ()
#  Coordinates:
#      lat           float64 8B 49.25
#      lon           float64 8B -123.0
#  Data variables:
#      SummerStart   float64 8B 138.0
#      SummerEnd     float64 8B 268.0
#      SummerTmax    float64 8B 226.0
#      SummerHeat    float64 8B 399.5
# ...

# %%
# get baseline
file_path = '../../../Data/ERA5-global/Baseline/computed_1961-1990-full_75th.nc'
c_75 = xr.open_dataarray(file_path)
c_75.values
# Out:
# array([[236.4370575 , 236.4370575 , 236.4370575 , ..., 236.4370575 ,
#         236.4370575 , 236.4370575 ],
#        [236.18743896, 236.1893158 , 236.19142151, ..., 236.18388367,
#         236.18530273, 236.18659973],
#        [235.91021729, 235.9200592 , 235.92704773, ..., 235.88049316,
#         235.8903656 , 235.90020752],
#        ...,
#        [270.7281189 , 270.72640991, 270.72720337, ..., 270.73239136,
#         270.73184204, 270.73007202],
#        [270.74356079, 270.74273682, 270.74200439, ..., 270.74594116,
#         270.74508667, 270.74420166],
#        [270.7550354 , 270.7550354 , 270.7550354 , ..., 270.7550354 ,
#         270.7550354 , 270.7550354 ]], shape=(721, 1440))

# %%
# get threshold for this location
thresh = c_75.sel(lat=input_lat, lon=input_lon, method="nearest")
print(thresh)
# Out:
# <xarray.DataArray 't2m' ()> Size: 8B
# array(286.88797)
# Coordinates:
#     lat       float64 8B 49.25
#     lon       float64 8B -123.0
#     quantile  float64 8B ...
# Attributes:
#     long_name:  75th percentile 2m Temperature for the data across available ...
#     units:      K

# %%
# %%time
# check computing the rolling avg for each grid cell

# min_periods = 2 to handle edges
ds_30dayroll2 = curr.t2m.rolling(time=30,center=True, min_periods=2).mean()
ds_30dayroll2
# Out:
# CPU times: user 8.08 ms, sys: 8.04 ms, total: 16.1 ms
# Wall time: 21.3 ms
# <xarray.DataArray 't2m' (time: 365)> Size: 1kB
# array([279.3119 , 279.3032 , 279.28036, 279.25354, 279.08447, 278.95892,
#        278.78238, 278.6446 , 278.5215 , 278.45648, 278.43866, 278.38998,
#        278.36523, 278.34393, 278.16388, 277.9298 , 277.7458 , 277.6869 ,
#        277.71075, 277.74152, 277.7309 , 277.68924, 277.6508 , 277.67313,
#        277.59677, 277.5294 , 277.57712, 277.48224, 277.30652, 277.18695,
#        277.05423, 276.89542, 276.7973 , 276.69708, 276.73642, 276.7657 ,
#        276.8841 , 276.97238, 276.89703, 276.6652 , 276.36627, 276.158  ,
#        276.02872, 275.8915 , 275.91858, 275.987  , 276.11893, 276.13297,
#        276.1034 , 276.02634, 275.9181 , 275.84897, 275.7945 , 275.7381 ,
#        275.79727, 275.7812 , 275.7202 , 275.75662, 275.74652, 275.73248,
#        275.77783, 275.91733, 276.08664, 276.28897, 276.437  , 276.56317,
# ...

# %%
# data
cell_lat = curr.lat.values
cell_lon = curr.lon.values
yr = curr.time.dt.year.values[0]
x1 = curr.time.dt.dayofyear.values
y1 = curr.t2m.values

# %%
# Fourier fit, up to 4th harmonic (mean + 3 more) as in Weller et al 2020
ymean = np.mean(y1)
y_norm = y1 - ymean
# perform DFT of temp data
coef = fft(y_norm)
# low-pass filter: retain only the mean and the first three harmonics, set all other frequencies to zero
# help from https://kls2177.github.io/Climate-and-Geophysical-Data-Analysis/chapters/Week6/filtering_in_freq2.html
Z_lp = np.copy(coef)
Z_lp[4:-3:] = 0.0  # we have to set both the positive and negative frequencies to zero
# apply inverse fourier transform to convert back to time domain (just want the real part)
y_norm_lp = np.real(np.fft.ifft(Z_lp))

# add back in the original mean temp
y_lp = y_norm_lp + ymean

# find length, start, and end using up to 4th harmonic
# use fit to get stats
summer_length = np.count_nonzero(y_lp >= thresh.values)
summer_days = np.where(y_lp >= thresh.values)[0]
print(summer_length)

# create some x values for plotting polynomial fit
x_values = np.linspace(min(x1), max(x1), 365) 

# otherwise can get start/end days 
first_day = int(x_values[min(summer_days)])
#OLD:# last_day = int(x_values[max(summer_days)])

# end day comes after first day so find next crossing of poly fit
# this is to be careful to not count until the end of a double crossing
end_window = np.where((y_lp[first_day:365]) < thresh.values)

# if it does cross back below threshold before the end of the "year"
if np.count_nonzero(end_window):
    last_day = end_window[0][0] + first_day

# polynomial fit, degree 3 as in Wang et al 2021
coefs = np.polyfit(x1, y1, 3)
poly = np.poly1d(coefs)
# Out:
# 131

# %%
# plot with all smoothing options
plt.figure(figsize=(16,6))
plt.plot(x1,y1, label='daily mean T2m')
plt.plot(x1, poly(x1), label='fitted degree 3 polynomial', color='orange')
plt.plot(x1, ds_30dayroll2.values, color='green', label='rolling')
plt.plot(x1, y_lp, label='Fourier fit 1-4th Harmonic', color='red')
plt.axhline(thresh.values, color="black", linewidth=0.8, linestyle="dashed") 

plt.axvline(first_day, color="black", linewidth=0.8, linestyle="dashed")
plt.axvline(last_day, color="black", linewidth=0.8, linestyle="dashed")

plt.xlabel('DOY (' + str(yr) + ')')
plt.ylabel('Mean Daily Temp (K)')
plt.annotate('75th percentile = '+str(np.round(thresh.values,1))+'K', xy=(0,thresh.values+1), fontsize=18)
plt.title(str(yr) + " Summer for Lat,Lon = [" +str(cell_lat)+","+str(cell_lon)+ "] Baseline Years = (1961-1990)")
plt.legend()
plt.show()

# %%
# get RMSE values

# RMSE for Fourier fit
rmse_rolling = np.sqrt(np.sum((y1-ds_30dayroll2.values)**2)/365.0)
rmse_poly = np.sqrt(np.sum((y1-poly(x1))**2)/365.0)
rmse_fourier = np.sqrt(np.sum((y1-y_lp)**2)/365.0)

# print them out
print("Poly fit RMSE = "+str(np.round(rmse_poly,4)))
print("Rolling avg fit RMSE = "+str(np.round(rmse_rolling,6)))
print("Fourier fit RMSE = "+str(np.round(rmse_fourier,4)))
# Out:
# Poly fit RMSE = 3.4497
# Rolling avg fit RMSE = 2.216628
# Fourier fit RMSE = 2.4016

# %%
# another plot without moving average for the paper


# polynomial fit, degree 3 as in Wang et al 2021
coefs = np.polyfit(x1, y1, 3)
poly = np.poly1d(coefs)

plt.figure(figsize=(16,6))
plt.plot(x1,y1, label='daily mean T2m', color="black", linewidth=1)
plt.plot(x1, poly(x1), label='fitted degree 3 polynomial', linewidth=2, color='orange')
#plt.plot(x1, ds_30dayroll2.values, color='green', label='rolling')
plt.plot(x1, y_lp, label='Fourier fit 1-4th Harmonic', linewidth=2, color='red')
plt.axhline(thresh.values, color="black", linewidth=0.8, linestyle="dashed") 

plt.axvline(first_day, color="black", linewidth=0.8, linestyle="dashed")
plt.axvline(last_day, color="black", linewidth=0.8, linestyle="dashed")

plt.xlabel('DOY (' + str(yr) + ')')
plt.ylabel('Mean Daily Temp (K)')
plt.annotate('75th percentile = '+str(np.round(thresh.values,1))+'K', xy=(0,thresh.values+1), fontsize=18)
plt.title(str(yr) + " Summer for Lat,Lon = [" +str(cell_lat)+","+str(cell_lon)+ "] Baseline Years = (1961-1990)")
plt.legend()
plt.show()

# %% [markdown]
# #### Plot for paper

# %%
# plot properties so I can more easily tweak them
s = 18
lw = 4
alpha = 0.6
fs = 18
sns.set_theme(context='notebook', style='darkgrid')#, font_scale=0.8)
#sns.set_context('poster', font_scale = 1)

# another plot without moving average for the paper

# conversion factor for K to deg C for plotting
KtoC = -273.15


# polynomial fit, degree 3 as in Wang et al 2021
coefs = np.polyfit(x1, y1, 3)
poly = np.poly1d(coefs)
summer_days_poly = np.where(poly(x1) >= thresh.values)[0]
print(summer_days_poly)

# create some x values for plotting polynomial fit
x_values_poly = np.linspace(min(x1), max(x1), 365) 

# otherwise can get start/end days 
first_day_poly = int(x_values[min(summer_days_poly)])
last_day_poly = int(x_values[max(summer_days_poly)])
print(first_day_poly, last_day_poly)

# convert to Celsius for paper
y1 = y1 + KtoC
y_lp = y_lp + KtoC
thresh = thresh + KtoC
y_poly = poly(x1) + KtoC

plt.figure(figsize=(12,6))
plt.plot(x1,y1, label='daily mean T2m', color="black", linewidth=1, alpha = 0.7)
plt.plot(x1, y_poly, label='fitted degree 3 polynomial', linewidth=2, color='orange')
#plt.plot(x1, ds_30dayroll2.values, color='green', label='rolling')
plt.plot(x1, y_lp, label='Fourier fit 1-4th Harmonic', linewidth=2, color='red')
plt.axhline(thresh.values, color="black", linewidth=0.8, linestyle="dashed") 

plt.axvline(first_day, color="red", linewidth=1.2, linestyle="dashed")
plt.axvline(last_day, color="red", linewidth=1.2, linestyle="dashed")

plt.axvline(first_day_poly, color="orange", linewidth=1.5, linestyle="dashed")
plt.axvline(last_day_poly, color="orange", linewidth=1.5, linestyle="dashed")

plt.xlabel('DOY\n', fontsize=fs)
plt.ylabel('Mean Daily Temp [$^{\circ}$C]', fontsize=fs)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.annotate('Threshold = '+str(np.round(thresh.values,1))+r'$^\circ$C', xy=(0,thresh.values+1), fontsize=18)
plt.title("Vancouver "+str(yr), fontsize=fs+6)
plt.savefig("./Plots/2023_Vancouver_Fourier_vs_poly.png",bbox_inches='tight')
plt.savefig("./Plots/2023_Vancouver_Fourier_vs_poly.pdf",bbox_inches='tight')
plt.savefig("./Plots/2023_Vancouver_Fourier_vs_poly.eps",bbox_inches='tight')
#plt.legend()
plt.show()
# Out:
# <>:49: SyntaxWarning: invalid escape sequence '\c'
# <>:49: SyntaxWarning: invalid escape sequence '\c'
# /var/folders/x9/4cv754f12hv2bf6s__9xrzj80000gp/T/ipykernel_2094/2918805239.py:49: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Mean Daily Temp [$^{\circ}$C]', fontsize=fs)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [156 157 158 159 160 161 162 163 164 165 166 167 168 169 170 171 172 173
#  174 175 176 177 178 179 180 181 182 183 184 185 186 187 188 189 190 191
#  192 193 194 195 196 197 198 199 200 201 202 203 204 205 206 207 208 209
#  210 211 212 213 214 215 216 217 218 219 220 221 222 223 224 225 226 227
#  228 229 230 231 232 233 234 235 236 237 238 239 240 241 242 243 244 245
#  246 247 248 249 250 251 252 253 254 255 256 257 258 259 260 261 262 263
#  264 265 266 267 268 269 270 271 272 273 274 275 276 277 278 279 280 281
#  282]
# 157 283

# %%
first_day_poly-first_day, last_day_poly-last_day
# Out:
# (19, np.int64(15))

# %%
last_day-first_day, last_day_poly-first_day_poly
# Out:
# (np.int64(130), 126)
