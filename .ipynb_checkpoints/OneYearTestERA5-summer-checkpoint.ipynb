# %% [markdown]
# ## Read in 12 months of daily mean T2m files and compute the 75th percentile temp for each cell to identify "summer" for that year as a test

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import netCDF4
from netCDF4 import Dataset
from datetime import datetime as dt

# %%
file_path = '../../../Data/ERA5-global/Baseline/1980/*.nc'

# open without dask chunking and see if it crashes
#ds = xr.open_mfdataset(file_path) #, chunks={'time': 10})

# can't do quantile calc unless we are chunked
ds = xr.open_mfdataset(file_path, chunks={'latitude': 10, 'longitude': 10})

# %%
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:      (time: 366, lat: 721, lon: 1440)
# Coordinates:
#   * time         (time) datetime64[ns] 3kB 1980-01-01 1980-01-02 ... 1980-12-31
#     realization  int64 8B 0
#   * lat          (lat) float64 6kB -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lon          (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
# Data variables:
#     t2m          (time, lat, lon) float32 2GB dask.array<chunksize=(31, 721, 1440), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.7
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      2024-05-23T10:38 GRIB to CDM+CF via cfgrib-0.9.9.1/ecCodes-...
#     source:       ECMWF

# %%
ds.nbytes
# Out:
# 1520003584

# %% [markdown]
# ### one year is 1.5 GB!! <br>

# %% [markdown]
# ### plot global mean temp across the year, weighted by latitude

# %%
# can weight these cells use cos(lat) because it is a regular grid
# need to look up or ask what this is saying - kinda get it but just to be sure!

weights = np.cos(np.deg2rad(ds.lat))
weights.name = "weights" # not sure why we did this since we aren't merging with the dataset but OK

# get weighted spatial mean
ds_t2m_ts = ds.weighted(weights).mean(["lon","lat"])
ds_t2m_ts
# Out:
# <xarray.Dataset> Size: 6kB
# Dimensions:      (time: 366)
# Coordinates:
#   * time         (time) datetime64[ns] 3kB 1980-01-01 1980-01-02 ... 1980-12-31
#     realization  int64 8B 0
# Data variables:
#     t2m          (time) float64 3kB dask.array<chunksize=(31,), meta=np.ndarray>

# %%
# plot the time series
fig,ax = plt.subplots(1,1, figsize=(10,4))
ds_t2m_ts.t2m.plot()
ax.set_ylabel("2m Air Temp (K)")
#ax.xaxis.set_tick_params(rotation=45)
plt.suptitle("Global Mean T2m 1980 (weighted by cos(lat))")
plt.title("")
# Out:
# Text(0.5, 1.0, '')

# %%
ds.chunks
# Out:
# Frozen({'time': (31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31), 'lat': (721,), 'lon': (1440,)})

# %% [markdown]
# ### compute 75th percentile values for each grid cell

# %%
# load it into memory because I can't do quantile on on the dask dataset (also can't figure out how to do percentile)
ds.load()
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:      (time: 366, lat: 721, lon: 1440)
# Coordinates:
#   * time         (time) datetime64[ns] 3kB 1980-01-01 1980-01-02 ... 1980-12-31
#     realization  int64 8B 0
#   * lat          (lat) float64 6kB -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lon          (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
# Data variables:
#     t2m          (time, lat, lon) float32 2GB 244.4 244.4 244.4 ... 248.7 248.7
# Attributes:
#     Conventions:  CF-1.7
#     institution:  European Centre for Medium-Range Weather Forecasts
#     history:      2024-05-23T10:38 GRIB to CDM+CF via cfgrib-0.9.9.1/ecCodes-...
#     source:       ECMWF

# %%
# Out:
# 1520003584

# %%
# %%time
#c_75 = ds.t2m.where(ds.t2m != 0).quantile(0.75, dim=('time'))
c_75 = ds.t2m.quantile(0.75, dim=('time'))
c_75
# Out:
# CPU times: user 27 s, sys: 318 ms, total: 27.3 s
# Wall time: 27.3 s
# <xarray.DataArray 't2m' (lat: 721, lon: 1440)> Size: 8MB
# array([[236.90471649, 236.90471649, 236.90471649, ..., 236.90471649,
#         236.90471649, 236.90471649],
#        [236.55875778, 236.55904007, 236.5591011 , ..., 236.55800247,
#         236.55845642, 236.55863571],
#        [236.50688934, 236.50760269, 236.50787354, ..., 236.5053215 ,
#         236.50579071, 236.50622559],
#        ...,
#        [269.8968277 , 269.8964386 , 269.89590454, ..., 269.8978653 ,
#         269.89752197, 269.89718628],
#        [269.9214859 , 269.92115021, 269.9212265 , ..., 269.92185211,
#         269.92188263, 269.92153931],
#        [270.1100235 , 270.1100235 , 270.1100235 , ..., 270.1100235 ,
#         270.1100235 , 270.1100235 ]])
# Coordinates:
#   * lat       (lat) float64 6kB -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lon       (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
# ...

# %% [markdown]
# ### plot one grid cell's time series and when it is above 75th percentile for the year, a.k.a. "summer"

# %%
# plot for specific grid cell and the 75th percentile
plot_data = ds.t2m.sel(lat=49.25,lon=-123.1, method="nearest") # Vancouver 49.246292, -123.116226
plot_c_75 = c_75.sel(lat=49.25,lon=-123.1, method="nearest")
plt.figure(figsize=(16,4))
plt.plot(plot_data.time, plot_data.data)
plt.fill_between(  # plot with color in between
    plot_data.time,  # x values
    # top boundary - y values above 0.5
    plot_data.data,
    plot_c_75,  # bottom boundary - 0.5
    where=(plot_data >= plot_c_75),
    color="red",  # color
    alpha=0.9,  # transparency value
    interpolate=True
)
plt.axhline(plot_c_75, color="red", linewidth=0.8, linestyle="dashed")
plt.tick_params(axis='x',rotation=45)
plt.xticks(["1980-01","1980-02","1980-03","1980-04","1980-05","1980-06",
           "1980-07","1980-08","1980-09","1980-10","1980-11","1980-12","1981-01"])
plt.grid()
#plt.ylim([280,315])
plt.title("Daily temps for Lat,Lon = [49.25,-123.1] and above 75th Percentile dates")
plt.xlabel("Date")
plt.ylabel("Daily Temp (K)")
# Out:
# Text(0, 0.5, 'Daily Temp (K)')

# %% [markdown]
# ### to-do
# - fit polynomial? use harmonic? Use 5 consecutive days?
#     - with polynomial, Wang (2021) used degree 3. Need to convert the x axis into "days" (using time.dt.dayofyear) to use np.polyfit (https://www.slingacademy.com/article/how-to-use-numpys-polyfit-for-polynomial-fitting/)
# - find intersections
# - get duration in days - use where() to get those above threshold and then count days
# - don't forget to deal with leap-years! Do we drop Feb 29 or average with Feb 28 and then drop? Average first seems good because it will work for S Hemisphere!

# %%
#plot_data
plot_c_75
# Out:
# <xarray.DataArray 't2m' ()> Size: 8B
# array(286.74971771)
# Coordinates:
#     lat       float64 8B 49.25
#     lon       float64 8B -123.0
#     quantile  float64 8B 0.75

# %%
plot_data.time.dt.dayofyear
# Out:
# <xarray.DataArray 'dayofyear' (time: 366)> Size: 3kB
# array([  1,   2,   3, ..., 364, 365, 366])
# Coordinates:
#   * time         (time) datetime64[ns] 3kB 1980-01-01 1980-01-02 ... 1980-12-31
#     realization  int64 8B 0
#     lat          float64 8B 49.25
#     lon          float64 8B -123.0
# Attributes:
#     long_name:         time
#     standard_name:     time
#     axis:              T
#     stored_direction:  increasing
#     type:              double

# %%
x1 = plot_data.time.dt.dayofyear.values
y1 = plot_data.values
#x1, y1
coefs = np.polyfit(x1, y1, 3)
poly = np.poly1d(coefs)

# %%
x_values = np.linspace(min(x1), max(x1), 366) # create some x values for plotting polynomial fit
plt.plot(x1,y1, label='data')
plt.plot(x_values, poly(x_values), label='fitted degree 3 polynomial', color='red')
plt.axhline(plot_c_75, color="black", linewidth=0.8, linestyle="dashed") 
plt.legend()

# %% [markdown]
# #### find summer length and also which days to add to figure

# %%
summer_length = np.count_nonzero(poly(x_values) >= plot_c_75.values)
summer_length
# Out:
# 88

# %%
summer_days = np.where(poly(x_values) >= plot_c_75.values)[0]
summer_days
# Out:
# array([171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183,
#        184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196,
#        197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209,
#        210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222,
#        223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235,
#        236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248,
#        249, 250, 251, 252, 253, 254, 255, 256, 257, 258])

# %%
first_day = x_values[min(summer_days)]
last_day = x_values[max(summer_days)]
first_day, last_day
# Out:
# (172.0, 259.0)

# %%
# make a new plot
x_values = np.linspace(min(x1), max(x1), 366) # create some x values for plotting polynomial fit
plt.figure(figsize=(16,6))
plt.plot(x1,y1, label='daily mean T2m')
plt.plot(x_values, poly(x_values), label='fitted degree 3 polynomial', color='red')
plt.axhline(plot_c_75.values, color="black", linewidth=0.8, linestyle="dashed") 
plt.axvline(first_day, color="black", linewidth=0.8, linestyle="dashed")
plt.axvline(last_day, color="black", linewidth=0.8, linestyle="dashed")
plt.annotate('summer = '+str(summer_length)+' days', xy=(first_day+5,280))
plt.annotate('75th percentile = '+str(np.round(plot_c_75.values,1))+'K', xy=(0,plot_c_75.values+1))
plt.xlabel('DOY (1980)')
plt.ylabel('Mean Daily Temp (K)')
plt.title("Summer for Lat,Lon = [49.25,-123.1] Baseline Years = 1980")
plt.legend()

# %% [markdown]
# ### to-do:
# - still deal with leap years
# - write as function so we can process entire globe and store values as additional var in xarray object

# %% [markdown]
# ## Function and workflow scaffold idea
# - for loop through all lat/lon values
# - calls SummerStats for each grid cell
# - gets back summer start (DOY), end, and length (could be smarter to reduce size and only return start and length since end can be computed)
# - produces a plot like above for the grid cell and saves it
# - adds those values to data array as additional variables

# %%
# attempt a function that takes in the data for a specific lat/lon and returns the start/end,length of summer
# and generates a plot if requested?
def SummerStats(temp_data, threshold, save_plot):
    '''

    Function that uses the input 75th percentile temperature in K to identify the summer from a time series of temperatures

    Args:
        temp_data: xarray of temperature data for a single grid cell
        threshold: xarray for the 75th percentile threshold to use
        save_plot: save out a png of the time series with threshold, summer start/end shown
        
    Returns:
        start day, end day, summer length
        
    Example:
        start_day, last_day, summer_length = SummerStats(input_temps, input_thresh, True)

    '''
    # extract DOY and T2m values for those days
    x1 = temp_data.time.dt.dayofyear.values
    y1 = temp_data.values

    #print(x1, y1)
    # polynomial fit, degree 3 as in Wang et al 2021
    coefs = np.polyfit(x1, y1, 3)
    poly = np.poly1d(coefs)

    ## *** TO-DO *** x_values needs to deal with leap years if not already handled
    x_values = np.linspace(min(x1), max(x1), 366) # create some x values for plotting polynomial fit

    # use fit to get stats
    summer_length = np.count_nonzero(poly(x_values) >= threshold.values)
    summer_days = np.where(poly(x_values) >= threshold.values)[0]

    # deal with grids that didn't have days above threshold
    if summer_length == 0:
        first_day = 0
        last_day = 0
    else: 
        first_day = x_values[min(summer_days)]
        last_day = x_values[max(summer_days)]

    # make and save plot if desired
    ##
    ##
    if save_plot:
        cell_lat = temp_data.lat.values
        cell_lon = temp_data.lon.values
        yr = temp_data.time.dt.year.values[0]

        plt.figure(figsize=(16,6))
        plt.plot(x1,y1, label='daily mean T2m')
        plt.plot(x_values, poly(x_values), label='fitted degree 3 polynomial', color='red')
        plt.axhline(threshold.values, color="black", linewidth=0.8, linestyle="dashed") 
        plt.axvline(first_day, color="black", linewidth=0.8, linestyle="dashed")
        plt.axvline(last_day, color="black", linewidth=0.8, linestyle="dashed")
        plt.annotate('summer = '+str(summer_length)+' days', xy=(first_day+5,np.mean(poly(x_values))), fontsize=18)
        plt.annotate('75th percentile = '+str(np.round(threshold.values,1))+'K', xy=(0,threshold.values+1), fontsize=18)
        plt.xlabel('DOY (' + str(yr) + ')')
        plt.ylabel('Mean Daily Temp (K)')
        plt.title("Summer for Lat,Lon = [" +str(cell_lat)+","+str(cell_lon)+ "] Baseline Years = 1980")
        plt.legend()
        plt.savefig("polyfit_stats_"+str(cell_lat)+"_"+str(cell_lon)+"_"+str(yr)+".png")
        plt.show()

    # return
    return first_day, last_day, summer_length

# %%
### test with Kiribati
input_lat = 1.0 + 28.0/60.0
input_lon = 173.0 + 2.0/60.0
input_thresh = c_75.sel(lat=input_lat,lon=input_lon, method="nearest")
input_temps = ds.t2m.sel(lat=input_lat,lon=input_lon, method="nearest") # Vancouver is 49.246292, -123.116226

start_day, last_day, summer_length = SummerStats(input_temps, input_thresh, True)
# x1 = input_temps.time.dt.dayofyear.values
# y1 = input_temps.values

# #print(x1, y1)
# # polynomial fit, degree 3 as in Wang et al 2021
# coefs = np.polyfit(x1, y1, 3)
# poly = np.poly1d(coefs)

# ## *** TO-DO *** x_values needs to deal with leap years if not already handled
# x_values = np.linspace(min(x1), max(x1), 366) # create some x values for plotting polynomial fit

# # use fit to get stats
# summer_length = np.count_nonzero(poly(x_values) >= input_thresh.values)
# summer_days = np.where(poly(x_values) >= input_thresh.values)[0]

# print(summer_length, summer_days)
#first_day = x_values[min(summer_days)]
#last_day = x_values[max(summer_days)]

# %% [markdown]
# ### <br> OK, for Kiribati in 1980 there was no time when the polynomial fit was above the 75th percentile, so this might indicate an issue with the "tropics" that might mean we do have to restrict the lat/lon values to extratropics??? <br>

# %%
# try again for a somewhat random spot in the extratropics of the Pacific Ocean (30 deg north of Kiribati)

input_lat = 1.0 + 28.0/60.0 + 30.0
input_lon = 173.0 + 2.0/60.0
input_thresh = c_75.sel(lat=input_lat,lon=input_lon, method="nearest")
input_temps = ds.t2m.sel(lat=input_lat,lon=input_lon, method="nearest") # Vancouver is 49.246292, -123.116226

start_day, last_day, summer_length = SummerStats(input_temps, input_thresh, True)

# %% [markdown]
# ## Cool! OK, still need to
# - deal with leap years
# - try looping through a range of lat/lon and test performance
# - append results for the grid cell back into the xarray, or build a new xarray object
# - consider trying a 5th degree polynomial and/or the 4th harmonic method of Park & Weller papers
# - make maps! 75th percentile, summer length w/ time slope, coastal/ocean/land, and more

# %% [markdown]
# ### Make a map of the 75th percentile temps from 1980

# %%
# should be able to make the 75th percentile map right now even though it is only from one year (1980)
#plt.figure(figsize=(12,6))
#c_75.plot()

# %%
# plot first time entry
fig = plt.figure(figsize=(12,6))

# assign axis and def projection to use
ax = plt.axes(projection=ccrs.Robinson(central_longitude=0))

# add coastlines and grid
ax.coastlines()
ax.gridlines()

# plot first index of SSTs
c_75.plot(
    ax=ax,
    transform=ccrs.PlateCarree(), # assign map projection
    vmin=230,
    vmax=310, # define temp range for colorbar 230 to 310 K
    cmap="coolwarm"
)

plt.title("75th Percentile T2m from 1980")
# Out:
# Text(0.5, 1.0, '75th Percentile T2m from 1980')

# %% [markdown]
# ### <br> Test out looping through lat,lon for performance and building the output <br><br>

# %%
c_75
# Out:
# <xarray.DataArray 't2m' (lat: 721, lon: 1440)> Size: 8MB
# array([[236.90471649, 236.90471649, 236.90471649, ..., 236.90471649,
#         236.90471649, 236.90471649],
#        [236.55875778, 236.55904007, 236.5591011 , ..., 236.55800247,
#         236.55845642, 236.55863571],
#        [236.50688934, 236.50760269, 236.50787354, ..., 236.5053215 ,
#         236.50579071, 236.50622559],
#        ...,
#        [269.8968277 , 269.8964386 , 269.89590454, ..., 269.8978653 ,
#         269.89752197, 269.89718628],
#        [269.9214859 , 269.92115021, 269.9212265 , ..., 269.92185211,
#         269.92188263, 269.92153931],
#        [270.1100235 , 270.1100235 , 270.1100235 , ..., 270.1100235 ,
#         270.1100235 , 270.1100235 ]])
# Coordinates:
#   * lat       (lat) float64 6kB -90.0 -89.75 -89.5 -89.25 ... 89.5 89.75 90.0
#   * lon       (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#     quantile  float64 8B 0.75

# %% [markdown]
# ### Test loop for 100 grid points

# %%
#help (np.zeros_like) #(10,10)

### Example code
# pressure_data = 1000.0 + 5 * np.random.randn(5, 3, 4)
# pressure = xr.DataArray(
#     pressure_data, coords=[times, lats, lons], dims=['time', 'lat', 'lon']
# )
# pressure.attrs['units'] = 'hPa'
# pressure.attrs['standard_name'] = 'air_pressure'

# pressure

# %%
# set up data arrays and grid cells to loop over
num_lat = 10
num_lon = 10

loop_lats = c_75.lat.values[:num_lat]
loop_lons = c_75.lon.values[:num_lon]


# empty data arrays for summer stats

summerlength = xr.DataArray(np.zeros((num_lat,num_lon)), 
                            coords=[loop_lats, loop_lons], 
                            dims=['lat','lon'])
summerstart = xr.DataArray(np.zeros((num_lat,num_lon)), 
                           coords=[loop_lats, loop_lons], 
                           dims=['lat','lon'])
summerend = xr.DataArray(np.zeros((num_lat,num_lon)), 
                         coords=[loop_lats, loop_lons], 
                         dims=['lat','lon'])

# %%
# finally figured out how to replace values without using the indices???
#summerlength['lat'==-90, 'lon'==-180] = 100

# %% [markdown]
# ## WRONG - still need to figure out how to replace individual values and what indexing to use <br> the below function is close but gotta update the last part. Might need to loop over index values instead of coordinates (use isel instead of sel for example)

# %% [markdown]
# ## figured it out!!! use loc[lat,lon] like summerlength.loc[input_lat, input_lon] : works as long as order is correct

# %%
# %%time

# for printing every X grids
counter = 1

# loop through all of the lat,lon of interest
for input_lat in loop_lats:
    for input_lon in loop_lons:

        # get threshold from c_75
        thresh = c_75.sel(lat=input_lat,lon=input_lon)
        #print("Threshold for lat=" + str(input_lat) + " lon=" + str(input_lon) + " is " + str(thresh.values))

        # all the temps for that grid cell over time
        temps = ds.t2m.sel(lat=input_lat,lon=input_lon) # this is a single year's dataset right now

        # build summer stats for the grid cell and produce the plot if desired

        #produce the time series plot with summer stats for every 5 cells
        # if (counter % 10 == 0):
        #     start_day, last_day, summer_length = SummerStats(temps, thresh, True)
        # else:
        #     start_day, last_day, summer_length = SummerStats(temps, thresh, False)

        # skip plots for now
        start_day, last_day, summer_length = SummerStats(temps, thresh, False)
        #print("Start, end, length are " + str(start_day) + " " + str(last_day) + " " + str(summer_length))
        
        # xarray requires strange indexing in order to replace values by coordinate
        summerstart.loc[input_lat, input_lon] = start_day
        summerend.loc[input_lat, input_lon] = last_day
        summerlength.loc[input_lat, input_lon] = summer_length

        counter +=1
# Out:
# CPU times: user 92.1 ms, sys: 15.3 ms, total: 107 ms
# Wall time: 120 ms

# %%
summerlength
# Out:
# <xarray.DataArray (lat: 10, lon: 10)> Size: 800B
# array([[75., 75., 75., 75., 75., 75., 75., 75., 75., 75.],
#        [76., 76., 76., 76., 76., 76., 76., 76., 76., 76.],
#        [75., 75., 75., 75., 75., 75., 75., 75., 75., 75.],
#        [77., 77., 77., 77., 77., 76., 76., 76., 76., 76.],
#        [78., 78., 78., 78., 78., 78., 78., 78., 78., 77.],
#        [74., 74., 74., 74., 74., 74., 74., 74., 74., 74.],
#        [70., 71., 71., 71., 71., 71., 71., 72., 72., 72.],
#        [69., 69., 69., 69., 69., 69., 69., 69., 69., 67.],
#        [69., 69., 69., 69., 69., 68., 68., 68., 68., 68.],
#        [67., 66., 66., 66., 66., 66., 66., 66., 66., 66.]])
# Coordinates:
#   * lat      (lat) float64 80B -90.0 -89.75 -89.5 -89.25 ... -88.25 -88.0 -87.75
#   * lon      (lon) float64 80B -180.0 -179.8 -179.5 ... -178.2 -178.0 -177.8

# %%
#summerlength.sel(lat=-89.5, lon=-178.0)
#summerlength.loc[-89.75, -178.0] = 11
#summerlength

# %% [markdown]
# ### Test out merging data arrays into a dataset

# %%
# ds = xr.Dataset(data_vars={'Temperature': temp, 'Pressure': pressure})
# ds

sum_ds = xr.Dataset(data_vars={'Threshold':c_75, 'SummerLength':summerlength})
sum_ds
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:       (lat: 721, lon: 1440)
# Coordinates:
#   * lat           (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * lon           (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#     quantile      float64 8B 0.75
# Data variables:
#     Threshold     (lat, lon) float64 8MB 236.9 236.9 236.9 ... 270.1 270.1 270.1
#     SummerLength  (lat, lon) float64 8MB 75.0 75.0 75.0 75.0 ... nan nan nan nan

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
sum_ds.SummerLength.plot()
plt.subplot(122)
sum_ds.SummerLength.plot()
plt.xlim(-180,-175)
plt.ylim(-90, -85)
plt.show()
plt.tight_layout()

# %% [markdown]
# ## That's some real progress!!!
