# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# %%
# outgoing longwave radiation from https://brian-rose.github.io/ClimateLaboratoryBook/courseware/models-budgets-fun.html

sigma = 5.67E-8 # Stefan-Boltzmann W m-2 K-4
tau = 238.5 / sigma / 288**4 # transmissivity of atmo w// avg LR of 238.5 W/m^2 and T_avg = 288K

def OutLR(T):
    return tau*sigma*T**4

OutLR(292), (OutLR(292)-OutLR(288))/OutLR(288) # 4 deg warmer earth
# Out:
# (252.02860648282106, 0.05672371690910298)

# %%
# about 6% more emission to space if 4 deg warmer

# %%
T = np.linspace(230,300,10)
print(T)
# Out:
# [230.         237.77777778 245.55555556 253.33333333 261.11111111
#  268.88888889 276.66666667 284.44444444 292.22222222 300.        ]

# %%
OutLR(T)
# Out:
# array([ 97.01296462, 110.81625978, 126.04263951, 142.78670856,
#        161.14611645, 181.22155746, 203.1167706 , 226.93853964,
#        252.79669311, 280.80410428])

# %% [markdown]
# ### <br> OK, now working my way through the W1D1 Tutorial of Project Pythia intro to xarray at <br> https://comptools.climatematch.io/tutorials/W1D1_ClimateSystemOverview/student/W1D1_Tutorial1.html <br><br>

# %%
# create random 3D array of temps
rand_data = 283 + 5 * np.random.randn(5,3,4)
rand_data
# Out:
# array([[[289.16127582, 287.20698699, 272.54064271, 282.86774997],
#         [278.40060167, 286.31601125, 273.88829227, 288.06778194],
#         [287.08896363, 273.71573596, 282.26907463, 277.47874482]],
#
#        [[275.42035055, 278.14711905, 275.34933221, 277.75700467],
#         [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#         [275.73580486, 282.09685091, 288.79438385, 282.21574935]],
#
#        [[281.20964738, 287.26620976, 284.76891987, 283.74892286],
#         [282.42448477, 284.5169004 , 279.67052763, 278.98560167],
#         [278.73399423, 282.8935297 , 279.37239499, 280.13278266]],
#
#        [[286.66138541, 279.15719116, 288.75871778, 281.03356031],
#         [288.32736778, 288.39739951, 288.5923856 , 279.58852241],
#         [279.16909552, 283.99121444, 287.57632527, 280.5467756 ]],
#
#        [[276.59314735, 285.83315775, 287.12229415, 278.70089514],
#         [280.47951906, 286.72055422, 283.90138694, 284.06733412],
#         [286.88263788, 285.99970059, 292.8116731 , 283.47096631]]])

# %%
# make it an xarray DataArray
temperature = xr.DataArray(rand_data)
temperature
# Out:
# <xarray.DataArray (dim_0: 5, dim_1: 3, dim_2: 4)>
# array([[[289.16127582, 287.20698699, 272.54064271, 282.86774997],
#         [278.40060167, 286.31601125, 273.88829227, 288.06778194],
#         [287.08896363, 273.71573596, 282.26907463, 277.47874482]],
#
#        [[275.42035055, 278.14711905, 275.34933221, 277.75700467],
#         [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#         [275.73580486, 282.09685091, 288.79438385, 282.21574935]],
#
#        [[281.20964738, 287.26620976, 284.76891987, 283.74892286],
#         [282.42448477, 284.5169004 , 279.67052763, 278.98560167],
#         [278.73399423, 282.8935297 , 279.37239499, 280.13278266]],
#
#        [[286.66138541, 279.15719116, 288.75871778, 281.03356031],
#         [288.32736778, 288.39739951, 288.5923856 , 279.58852241],
#         [279.16909552, 283.99121444, 287.57632527, 280.5467756 ]],
#
#        [[276.59314735, 285.83315775, 287.12229415, 278.70089514],
#         [280.47951906, 286.72055422, 283.90138694, 284.06733412],
#         [286.88263788, 285.99970059, 292.8116731 , 283.47096631]]])
# Dimensions without coordinates: dim_0, dim_1, dim_2

# %%
# try that again but give it names dimensions
temperature = xr.DataArray(rand_data, dims=["time","lat","lon"])
temperature
# Out:
# <xarray.DataArray (time: 5, lat: 3, lon: 4)>
# array([[[289.16127582, 287.20698699, 272.54064271, 282.86774997],
#         [278.40060167, 286.31601125, 273.88829227, 288.06778194],
#         [287.08896363, 273.71573596, 282.26907463, 277.47874482]],
#
#        [[275.42035055, 278.14711905, 275.34933221, 277.75700467],
#         [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#         [275.73580486, 282.09685091, 288.79438385, 282.21574935]],
#
#        [[281.20964738, 287.26620976, 284.76891987, 283.74892286],
#         [282.42448477, 284.5169004 , 279.67052763, 278.98560167],
#         [278.73399423, 282.8935297 , 279.37239499, 280.13278266]],
#
#        [[286.66138541, 279.15719116, 288.75871778, 281.03356031],
#         [288.32736778, 288.39739951, 288.5923856 , 279.58852241],
#         [279.16909552, 283.99121444, 287.57632527, 280.5467756 ]],
#
#        [[276.59314735, 285.83315775, 287.12229415, 278.70089514],
#         [280.47951906, 286.72055422, 283.90138694, 284.06733412],
#         [286.88263788, 285.99970059, 292.8116731 , 283.47096631]]])
# Dimensions without coordinates: time, lat, lon

# %%
# create objects for the times and the lat/lon to add to the DataArray
times_index = pd.date_range("2018-01-01",periods=5) # cool how it knows this is "daily"
lons = np.linspace(-120,-60,4)
lats = np.linspace(25,55,3)
times_index, lons, lats
# Out:
# (DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                 '2018-01-05'],
#                dtype='datetime64[ns]', freq='D'),
#  array([-120., -100.,  -80.,  -60.]),
#  array([25., 40., 55.]))

# %%
# now create the full data array with these dimensions
temperature = xr.DataArray(
    rand_data, coords=[times_index, lats, lons], dims=["time","lat","lon"]
)
temperature
# Out:
# <xarray.DataArray (time: 5, lat: 3, lon: 4)>
# array([[[289.16127582, 287.20698699, 272.54064271, 282.86774997],
#         [278.40060167, 286.31601125, 273.88829227, 288.06778194],
#         [287.08896363, 273.71573596, 282.26907463, 277.47874482]],
#
#        [[275.42035055, 278.14711905, 275.34933221, 277.75700467],
#         [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#         [275.73580486, 282.09685091, 288.79438385, 282.21574935]],
#
#        [[281.20964738, 287.26620976, 284.76891987, 283.74892286],
#         [282.42448477, 284.5169004 , 279.67052763, 278.98560167],
#         [278.73399423, 282.8935297 , 279.37239499, 280.13278266]],
#
#        [[286.66138541, 279.15719116, 288.75871778, 281.03356031],
#         [288.32736778, 288.39739951, 288.5923856 , 279.58852241],
#         [279.16909552, 283.99121444, 287.57632527, 280.5467756 ]],
#
#        [[276.59314735, 285.83315775, 287.12229415, 278.70089514],
#         [280.47951906, 286.72055422, 283.90138694, 284.06733412],
#         [286.88263788, 285.99970059, 292.8116731 , 283.47096631]]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#   * lat      (lat) float64 25.0 40.0 55.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0

# %%
# add units to the temps
temperature.attrs["units"] = "kelvin"
temperature.attrs["standard_name"] = "air_temperature"
temperature
# Out:
# <xarray.DataArray (time: 5, lat: 3, lon: 4)>
# array([[[289.16127582, 287.20698699, 272.54064271, 282.86774997],
#         [278.40060167, 286.31601125, 273.88829227, 288.06778194],
#         [287.08896363, 273.71573596, 282.26907463, 277.47874482]],
#
#        [[275.42035055, 278.14711905, 275.34933221, 277.75700467],
#         [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#         [275.73580486, 282.09685091, 288.79438385, 282.21574935]],
#
#        [[281.20964738, 287.26620976, 284.76891987, 283.74892286],
#         [282.42448477, 284.5169004 , 279.67052763, 278.98560167],
#         [278.73399423, 282.8935297 , 279.37239499, 280.13278266]],
#
#        [[286.66138541, 279.15719116, 288.75871778, 281.03356031],
#         [288.32736778, 288.39739951, 288.5923856 , 279.58852241],
#         [279.16909552, 283.99121444, 287.57632527, 280.5467756 ]],
#
#        [[276.59314735, 285.83315775, 287.12229415, 278.70089514],
#         [280.47951906, 286.72055422, 283.90138694, 284.06733412],
#         [286.88263788, 285.99970059, 292.8116731 , 283.47096631]]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#   * lat      (lat) float64 25.0 40.0 55.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# now create a pressure object
pressure_data = 1000.0 + 5 * np.random.randn(5,3,4)
pressure = xr.DataArray(
     pressure_data, coords=[times_index, lats, lons], dims=["time","lat","lon"]
)
pressure.attrs["units"] = "hPa"
pressure.attrs["standard_name"] = "air_pressure"

pressure
# Out:
# <xarray.DataArray (time: 5, lat: 3, lon: 4)>
# array([[[1009.31488217,  998.30196969, 1004.04335552, 1001.97467146],
#         [1002.2907848 ,  996.12087577,  996.11359715, 1005.46857489],
#         [1006.2392264 , 1005.16398042, 1004.74674703, 1002.16246238]],
#
#        [[ 993.85971595, 1002.39992559,  996.62966231,  992.5745831 ],
#         [1005.3317367 , 1007.57629715, 1000.16814218,  993.74511903],
#         [1008.15415366, 1000.30256581,  996.2679134 ,  995.54684899]],
#
#        [[1000.66297092, 1005.10904189,  998.92996787,  994.58165185],
#         [ 993.53952461,  996.47853873, 1002.30403286,  995.61061089],
#         [1004.96071382,  992.25579143,  992.73279669, 1000.97194834]],
#
#        [[1006.9950976 ,  996.74209625, 1002.60294903, 1004.66420352],
#         [1005.51962033,  992.57478683, 1000.44015749, 1000.62386294],
#         [ 995.98777337, 1001.33922322,  998.15314842,  995.6776212 ]],
#
#        [[ 999.51728649, 1002.23502719,  999.72741555,  999.60857174],
#         [ 997.27013793, 1004.23038477, 1010.69813469,  998.21827655],
#         [ 997.01038389, 1002.92691701,  992.66438492, 1008.67182967]]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#   * lat      (lat) float64 25.0 40.0 55.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0
# Attributes:
#     units:          hPa
#     standard_name:  air_pressure

# %% [markdown]
# ### Merge into a Dataset Object

# %%
ds = xr.Dataset(data_vars={"Temperature": temperature, "Pressure": pressure})
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 5, lat: 3, lon: 4)
# Coordinates:
#   * time         (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#   * lat          (lat) float64 25.0 40.0 55.0
#   * lon          (lon) float64 -120.0 -100.0 -80.0 -60.0
# Data variables:
#     Temperature  (time, lat, lon) float64 289.2 287.2 272.5 ... 292.8 283.5
#     Pressure     (time, lat, lon) float64 1.009e+03 998.3 ... 992.7 1.009e+03

# %%
# looks like attrs are lost above?
# but they are still included in the DataArray object within the Dataset
ds.Pressure # also ds["Pressure"]
# Out:
# <xarray.DataArray 'Pressure' (time: 5, lat: 3, lon: 4)>
# array([[[1009.31488217,  998.30196969, 1004.04335552, 1001.97467146],
#         [1002.2907848 ,  996.12087577,  996.11359715, 1005.46857489],
#         [1006.2392264 , 1005.16398042, 1004.74674703, 1002.16246238]],
#
#        [[ 993.85971595, 1002.39992559,  996.62966231,  992.5745831 ],
#         [1005.3317367 , 1007.57629715, 1000.16814218,  993.74511903],
#         [1008.15415366, 1000.30256581,  996.2679134 ,  995.54684899]],
#
#        [[1000.66297092, 1005.10904189,  998.92996787,  994.58165185],
#         [ 993.53952461,  996.47853873, 1002.30403286,  995.61061089],
#         [1004.96071382,  992.25579143,  992.73279669, 1000.97194834]],
#
#        [[1006.9950976 ,  996.74209625, 1002.60294903, 1004.66420352],
#         [1005.51962033,  992.57478683, 1000.44015749, 1000.62386294],
#         [ 995.98777337, 1001.33922322,  998.15314842,  995.6776212 ]],
#
#        [[ 999.51728649, 1002.23502719,  999.72741555,  999.60857174],
#         [ 997.27013793, 1004.23038477, 1010.69813469,  998.21827655],
#         [ 997.01038389, 1002.92691701,  992.66438492, 1008.67182967]]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#   * lat      (lat) float64 25.0 40.0 55.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0
# Attributes:
#     units:          hPa
#     standard_name:  air_pressure

# %% [markdown]
# ## Tutorial 2 - finding subsets of data in the dataset

# %%
from datetime import timedelta

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 5, lat: 3, lon: 4)
# Coordinates:
#   * time         (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#   * lat          (lat) float64 25.0 40.0 55.0
#   * lon          (lon) float64 -120.0 -100.0 -80.0 -60.0
# Data variables:
#     Temperature  (time, lat, lon) float64 289.2 287.2 272.5 ... 292.8 283.5
#     Pressure     (time, lat, lon) float64 1.009e+03 998.3 ... 992.7 1.009e+03

# %%
# ways to select data on Jan 2 2018
indexed_sel = temperature[1, :, :] # index 1 along time axis 0
indexed_sel
# Out:
# <xarray.DataArray (lat: 3, lon: 4)>
# array([[275.42035055, 278.14711905, 275.34933221, 277.75700467],
#        [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#        [275.73580486, 282.09685091, 288.79438385, 282.21574935]])
# Coordinates:
#     time     datetime64[ns] 2018-01-02
#   * lat      (lat) float64 25.0 40.0 55.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# select one latitude
indexed_sel2 = temperature[:, 1, :] # index 1 along lat axis 1
indexed_sel2
# Out:
# <xarray.DataArray (time: 5, lon: 4)>
# array([[278.40060167, 286.31601125, 273.88829227, 288.06778194],
#        [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#        [282.42448477, 284.5169004 , 279.67052763, 278.98560167],
#        [288.32736778, 288.39739951, 288.5923856 , 279.58852241],
#        [280.47951906, 286.72055422, 283.90138694, 284.06733412]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#     lat      float64 40.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# can select by coord value too
named_sel = temperature.sel(time="2018-01-02")
named_sel
# Out:
# <xarray.DataArray (lat: 3, lon: 4)>
# array([[275.42035055, 278.14711905, 275.34933221, 277.75700467],
#        [284.24194686, 291.92790613, 280.82318625, 282.72365524],
#        [275.73580486, 282.09685091, 288.79438385, 282.21574935]])
# Coordinates:
#     time     datetime64[ns] 2018-01-02
#   * lat      (lat) float64 25.0 40.0 55.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# select a grid point based on lat/lon
coord_sel = temperature.sel(lat=25, lon=-120)
coord_sel
# Out:
# <xarray.DataArray (time: 5)>
# array([289.16127582, 275.42035055, 281.20964738, 286.66138541,
#        276.59314735])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#     lat      float64 25.0
#     lon      float64 -120.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# nearest neighbor sampling
# closest date within a tolerance
temperature.sel(time="2018-01-07", method="nearest", tolerance=timedelta(days=2))
# Out:
# <xarray.DataArray (lat: 3, lon: 4)>
# array([[276.59314735, 285.83315775, 287.12229415, 278.70089514],
#        [280.47951906, 286.72055422, 283.90138694, 284.06733412],
#        [286.88263788, 285.99970059, 292.8116731 , 283.47096631]])
# Coordinates:
#     time     datetime64[ns] 2018-01-05
#   * lat      (lat) float64 25.0 40.0 55.0
#   * lon      (lon) float64 -120.0 -100.0 -80.0 -60.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# %%time
# linear interpolation between points (downscaling?)
temperature.interp(lat=40, lon=-105, method="linear") # Boulder, CO lat/lon not in dataset
# Out:
# CPU times: user 5.62 ms, sys: 2.4 ms, total: 8.03 ms
# Wall time: 6.49 ms
# <xarray.DataArray (time: 5)>
# array([284.33715886, 290.00641631, 283.99379649, 288.37989158,
#        285.16029543])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02 ... 2018-01-05
#     lat      int64 40
#     lon      int64 -105
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# slicing using slice()
temperature.sel(
    time=slice("2018-01-01","2018-01-02"), 
    lon=slice(-110,-70),
    lat=slice(25,45)
)
# Out:
# <xarray.DataArray (time: 2, lat: 2, lon: 2)>
# array([[[287.20698699, 272.54064271],
#         [286.31601125, 273.88829227]],
#
#        [[278.14711905, 275.34933221],
#         [291.92790613, 280.82318625]]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-01 2018-01-02
#   * lat      (lat) float64 25.0 40.0
#   * lon      (lon) float64 -100.0 -80.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
# last method using loc[]
temperature.loc['2018-01-03':'2018-01-05',slice(25,45),-110:-70] # must be in order, can also use slice
# Out:
# <xarray.DataArray (time: 3, lat: 2, lon: 2)>
# array([[[287.26620976, 284.76891987],
#         [284.5169004 , 279.67052763]],
#
#        [[279.15719116, 288.75871778],
#         [288.39739951, 288.5923856 ]],
#
#        [[285.83315775, 287.12229415],
#         [286.72055422, 283.90138694]]])
# Coordinates:
#   * time     (time) datetime64[ns] 2018-01-03 2018-01-04 2018-01-05
#   * lat      (lat) float64 25.0 40.0
#   * lon      (lon) float64 -100.0 -80.0
# Attributes:
#     units:          kelvin
#     standard_name:  air_temperature

# %%
from pythia_datasets import DATASETS
