# %% [markdown]
# ## Is the day of max temp correlated with the start of summer?
# - over land?
# - only in the NH?
# -  can we confirm with another data set, like Berkeley Earth, which isn't re-analysis?

# %% [markdown]
# ![image.png](attachment:f3e27e08-71b5-4aaf-93db-fbc510add9eb.png)
