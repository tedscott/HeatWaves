# %% [markdown]
# # Rachel suggests looking into the gradient of the fit to the timeseries at the intersection with the threshold

# %% [markdown]
# # !!! ![image.png](attachment:869f9c9d-8e9c-48b3-94ce-08160f8912c0.png)
