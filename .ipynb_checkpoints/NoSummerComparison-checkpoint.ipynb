# %% [markdown]
# # Where and when does poly vs fourier say summer has length zero

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.stats as stats
from sklearn import linear_model
import statsmodels.api as sm
import seaborn as sns

from cartopy import crs as ccrs, feature as cfeature
import netCDF4
from netCDF4 import Dataset
from datetime import datetime as dt

# to get rid of runtime warnings when OLS fits hit a divide by zero - handled by setting R2 and p-vals appropriately
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read in both the poly fit data and fourier

# %%
# read in summer stats
input_path = '../../../Data/ERA5-global/Analysis/New-Fourier/1961-2023_ALL_summer_stats.nc'
ds_f = xr.open_dataset(input_path)

input_path = '../../../Data/ERA5-global/Analysis/New/1961-2023_ALL_summer_stats.nc'
ds_p = xr.open_dataset(input_path)

# %%
ds_f, ds_p
# Out:
# (<xarray.Dataset> Size: 5GB
#  Dimensions:       (lat: 721, lon: 1440, time: 63)
#  Coordinates:
#    * lat           (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#    * lon           (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#    * time          (time) datetime64[ns] 504B 1961-01-01 ... 2023-01-01
#  Data variables:
#      SummerStart   (time, lat, lon) float64 523MB ...
#      SummerEnd     (time, lat, lon) float64 523MB ...
#      SummerTmax    (time, lat, lon) float64 523MB ...
#      SummerHeat    (time, lat, lon) float64 523MB ...
#      SummerLength  (time, lat, lon) float64 523MB ...
#      SummerRMSE    (time, lat, lon) float64 523MB ...
#      SummerR2      (time, lat, lon) float64 523MB ...
#      SummerMeanT   (time, lat, lon) float64 523MB ...
#      SummerMeanHS  (time, lat, lon) float64 523MB ...
#      lsm           (time, lat, lon) float64 523MB ...
#      Coastal       (time, lat, lon) bool 65MB ...,
#  <xarray.Dataset> Size: 5GB
#  Dimensions:       (lat: 721, lon: 1440, time: 63)
#  Coordinates:
#    * lat           (lat) float64 6kB -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#    * lon           (lon) float64 12kB -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#    * time          (time) datetime64[ns] 504B 1961-01-01 ... 2023-01-01
#  Data variables:
#      SummerStart   (time, lat, lon) float64 523MB ...
#      SummerEnd     (time, lat, lon) float64 523MB ...
#      SummerTmax    (time, lat, lon) float64 523MB ...
#      SummerHeat    (time, lat, lon) float64 523MB ...
#      SummerLength  (time, lat, lon) float64 523MB ...
#      SummerRMSE    (time, lat, lon) float64 523MB ...
#      SummerR2      (time, lat, lon) float64 523MB ...
#      SummerMeanT   (time, lat, lon) float64 523MB ...
#      SummerMeanHS  (time, lat, lon) float64 523MB ...
#      lsm           (time, lat, lon) float64 523MB ...
#      Coastal       (time, lat, lon) bool 65MB ...)

# %%
ds_f.SummerLength.sel(time="2023").where(ds_f.SummerLength == 0).plot()

# %% [markdown]
# ## Will have to loop thru all lat/lon and gather all locations where Summerlength is zero across all years, I guess

# %%
gb = ds_f.SummerLength.where(ds_f.SummerLength == 0).groupby("time.year")
gb.map(np.count_nonzero)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 2
#       1 gb = ds_f.SummerLength.where(ds_f.SummerLength == 0).groupby("time.year")
# ----> 2 gb.map(np.count_nonzero)
#
# File ~/anaconda3/envs/climate/lib/python3.12/site-packages/xarray/core/groupby.py:1582, in DataArrayGroupByBase.map(self, func, args, shortcut, **kwargs)
#    1534 def map(
#    1535     self,
#    1536     func: Callable[..., DataArray],
#    (...)
#    1539     **kwargs: Any,
#    1540 ) -> DataArray:
#    1541     """Apply a function to each array in the group and concatenate them
#    1542     together into a new array.
#    1543
#    (...)
#    1580         The result of splitting, applying and combining this array.
#    1581     """
# -> 1582     return self._map_maybe_warn(
#    1583         func, args, warn_squeeze=True, shortcut=shortcut, **kwargs
#    1584     )
#
# File ~/anaconda3/envs/climate/lib/python3.12/site-packages/xarray/core/groupby.py:1601, in DataArrayGroupByBase._map_maybe_warn(self, func, args, warn_squeeze, shortcut, **kwargs)
#    1595 grouped = (
#    1596     self._iter_grouped_shortcut(warn_squeeze)
#    1597     if shortcut
#    1598     else self._iter_grouped(warn_squeeze)
#    1599 )
#    1600 applied = (maybe_wrap_array(arr, func(arr, *args, **kwargs)) for arr in grouped)
# -> 1601 return self._combine(applied, shortcut=shortcut)
#
# File ~/anaconda3/envs/climate/lib/python3.12/site-packages/xarray/core/groupby.py:1621, in DataArrayGroupByBase._combine(self, applied, shortcut)
#    1619 """Recombine the applied objects like the original."""
#    1620 applied_example, applied = peek_at(applied)
# -> 1621 coord, dim, positions = self._infer_concat_args(applied_example)
#    1622 if shortcut:
#    1623     combined = self._concat_shortcut(applied, dim, positions)
#
# File ~/anaconda3/envs/climate/lib/python3.12/site-packages/xarray/core/groupby.py:982, in GroupBy._infer_concat_args(self, applied_example)
#     980 def _infer_concat_args(self, applied_example):
#     981     (grouper,) = self.groupers
# --> 982     if self._group_dim in applied_example.dims:
#     983         coord = grouper.group1d
#     984         positions = self._group_indices
#
# AttributeError: 'int' object has no attribute 'dims'

# %%
yrs = [1996,1997,2005,2006] #np.arange(1996,1998,1)

# %%
# %%time


for yr in yrs:

    
    # FOURIER
    plt.figure(figsize=(10,6))
    # assign axis and def projection to use
    ax = plt.axes(projection=ccrs.Robinson(central_longitude=0))
    
    # add coastlines and grid
    ax.coastlines()
    ax.gridlines()
    
    ds_f.SummerLength.sel(time=str(yr)).where((ds_f.SummerLength == 0) & ((ds_f.lat >= 23.5) | (ds_f.lat <+ -23.5))).plot(
        ax=ax,
        transform=ccrs.PlateCarree(), # assign map projection
        #vmin=-0.7,
        #vmax=0.7, 
        #cmap="coolwarm",#"YlOrRd"#cmap="coolwarm"
        cbar_kwargs={'shrink': 0}
    )
    ax.set_title("Fourier Fit for "+str(yr))

    # POLY
    plt.figure(figsize=(10,6))
    # assign axis and def projection to use
    ax1 = plt.axes(projection=ccrs.Robinson(central_longitude=0))
    
    # add coastlines and grid
    ax1.coastlines()
    ax1.gridlines()
    
    ds_p.SummerLength.sel(time=str(yr)).where((ds_p.SummerLength == 0) & ((ds_p.lat >= 23.5) | (ds_p.lat <+ -23.5))).plot(
        ax=ax1,
        transform=ccrs.PlateCarree(), # assign map projection
        #vmin=-0.7,
        #vmax=0.7, 
        #cmap="coolwarm",#"YlOrRd"#cmap="coolwarm"
        cbar_kwargs={'shrink': 0}
    )
    ax1.set_title("Polynomial Fit for "+str(yr))


plt.show()
# Out:
# CPU times: user 24.5 s, sys: 637 ms, total: 25.1 s
# Wall time: 25.2 s

# %%
#ds_f.SummerLength.where(ds_f.SummerLength == 0).groupby("time.year").count()
np.count_nonzero(ds_f.SummerLength.where(ds_f.SummerLength == 0)), np.count_nonzero(ds_p.SummerLength.where(ds_p.SummerLength == 0))
# Out:
# (63112929, 53040003)
