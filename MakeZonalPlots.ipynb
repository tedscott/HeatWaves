# %% [markdown]
# ## Take in a series of years and produce zonal summer length plot of the series

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from cartopy import crs as ccrs, feature as cfeature
import netCDF4
from netCDF4 import Dataset
from datetime import datetime as dt

# %%
plot_years = [1960,1965,1970,1975,1980,1985,1990]

# %%
#

# %%
# plot mean across all longitudes for each year of interest

# create list of colors
colors_loc = plt.cm.coolwarm(np.linspace(0, 1, len(plot_years)))

# Make a zonal mean figure of the changes
plt.figure(figsize=(12,6))

# loop through the years and add to plot
for idx, year in enumerate(plot_years):
    input_path = '../../../Data/ERA5-global/Analysis/Temp/'+str(year)+'_summer_stats.nc'
    ds = xr.open_dataset(input_path)
    zonal_mean = ds.SummerLength.mean(dim='lon')
    latitude = ds.lat
    plt.plot(zonal_mean, latitude, 
             c=colors_loc[idx], label=str(year))

plt.axvline(x=0, color="gray", alpha=1, linestyle=":", linewidth=2)
plt.ylim(-95, 95)
plt.yticks(ticks=np.arange(-90,105,15))
plt.xlabel("Summer length (days)")
plt.ylabel("Latitude ($^{\circ}$)")
plt.title(
    str(plot_years[0]) + "-" + str(plot_years[-1]) + " Summer length by latitude (days)",  
    loc="center",
)
plt.legend()
plt.savefig(str(plot_years[0]) + "-" + str(plot_years[-1])+"_SummerLength_zonal.png")
plt.show()
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\c'
# <>:22: SyntaxWarning: invalid escape sequence '\c'
# /var/folders/x9/4cv754f12hv2bf6s__9xrzj80000gp/T/ipykernel_25476/3256774829.py:22: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel("Latitude ($^{\circ}$)")

# %%
# Out:
# array([-90, -75, -60, -45, -30, -15,   0,  15,  30,  45,  60,  75,  90])

# %%
import gc

# %%
gc.collect()
# Out:
# 808
